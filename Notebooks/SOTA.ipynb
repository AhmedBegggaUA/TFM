# %% [markdown]
# # Node classification practice

# %% [markdown]
# ## Bibliography and references you may find useful
# * Tutorial of Graph Rewiring: https://youtu.be/AumdG5bazhg (Here you can find a tutorial explaining the principal issues of the graph neural networks and how to solve them).
# * Pytorch Geometric: https://pytorch-geometric.readthedocs.io/en/latest/notes/introduction.html (Here you can find the documentation of the library we are going to use. Also, you can find some examples of how to use it and all the dataset available).
# ### Papers
# * Graph representation learning: https://arxiv.org/abs/1709.05584
# * Graph Convolutional Networks: https://arxiv.org/abs/1609.02907
# * Beyond Homophily in Graph Neural Networks: https://arxiv.org/pdf/2006.11468.pdf
# * Graph Attention Networks: https://arxiv.org/pdf/1710.10903.pdf
# * Large Scale Learning on Non-Homophilous Graphs: New Benchmarks and Strong Simple Methods: https://arxiv.org/abs/2110.14446

# %%
#Libraries we are going to use
# Install required packages.
import os
import torch #Library for deep learning
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

#!pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
#!pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
#!pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
#COLLAB_ENV = True
#if COLLAB_ENV:
#    !pip install 'scipy>=1.8'
#    !pip install mycolorpy
import numpy as np #Library for linear algebra
import matplotlib.pyplot as plt #Library for plotting
import networkx as nx #Library for graph
from torch_geometric.datasets import Planetoid,WebKB #Library for graph dataset and deep learning on graphs
from torch_geometric.utils import to_dense_adj
import warnings
warnings.filterwarnings("ignore") # Get rid of warnings
# Out:
# 1.12.1

# %% [markdown]
# ### 1. Load data and visualize it

# %%
'''
    Load the dataset:
        * root: The root directory where the dataset should be saved.
        * name: The name of the dataset (cora, citeseer or pubmed).
        * transform: A function/transform that takes in an Data object of the dataset and returns a transformed version. The data object will be transformed before every access.
    Returns:
        * Dataset object
'''
dataset = Planetoid(root='/tmp/Cora', name='Cora') # Load the Cora dataset
dataset = WebKB(root='/tmp/WebKB', name='Cornell') # Load the Cornell dataset
data = dataset[0] # Get the first graph object (in this case is only one graph, while in Graph classification there are multiple graphs) 
print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
print()
print(data) # Note that the adjacency matrix is not stored explicitly but in the edge_index attribute.
            # The edge_index attribute is a 2 x E tensor, with each column denoting an edge.
            # The first row denotes the source nodes and the second row the destination nodes of the edges.
            # The nodes are numbered consecutively starting from zero.
            # The features are stored in the x attribute, which is a N x F tensor, with N being the number of nodes and F the number of features per node.
            # The labels are stored in the y attribute, which is a vector of length N, with each entry denoting the class of the corresponding node.
print('===========================================================================================================')
adj = to_dense_adj(data.edge_index)[0] # Convert the sparse adjacency matrix to a dense adjacency matrix
print("Shape of the new adjacency matrix: ",adj.shape)
#Let's get statistics about the graph adjacency matrix
print("Number of nodes: ",adj.shape[0])
print("Number of edges: ",round(adj.sum().item()))
print("Density: ",round((adj.sum()/(adj.shape[0]*adj.shape[0])).item(),4))
print("Maximum node degree: ",round(adj.sum(axis=1).max().item()))
print("Minimum node degree: ",round(adj.sum(axis=1).min().item()))
print("Average node degree: ",round(adj.sum(axis=1).mean().item()))
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
print('===========================================================================================================')
# Out:
# Dataset: cornell():
# ======================
# Number of graphs: 1
# Number of features: 1703
# Number of classes: 5
#
# Data(x=[183, 1703], edge_index=[2, 298], y=[183], train_mask=[183, 10], val_mask=[183, 10], test_mask=[183, 10])
# ===========================================================================================================
# Shape of the new adjacency matrix:  torch.Size([183, 183])
# Number of nodes:  183
# Number of edges:  298
# Density:  0.0089
# Maximum node degree:  93
# Minimum node degree:  0
# Average node degree:  2
# Has isolated nodes: False
# Has self-loops: True
# Is undirected: False
# ===========================================================================================================

# %% [markdown]
# ### 1.1 Visualize the graph

# %%
# To visualize the graph we are going to use networkx library, but first we need to convert the graph to networkx format
from torch_geometric.utils import to_networkx
A = to_networkx(data, to_undirected=True) # Convert the graph to networkx format
# Now we are going to get the largest connected component of the graph, because the graph is not connected!
Gcc = sorted(nx.connected_components(A), key=len, reverse=True) # Get the sorted list of connected components
A = A.subgraph(Gcc[0]) # Get the largest connected component 
G = nx.adjacency_matrix(A)
# All the following code is just for plotting the graph, so you can ignore it
# This how we can get the edge_index attribute for the largest connected component
g_tensor = torch.tensor(G.todense())
new_edge_index = g_tensor.nonzero().t().contiguous()
# This is how we create the new data object for the largest connected component
data.x = data.x[list(A.nodes())]
data.y = data.y[list(A.nodes())]
data.edge_index = new_edge_index
data.num_nodes = len(A.nodes())
data.num_edges = len(A.edges())
print(data)
# Now we can plot the graph
A = to_networkx(data, to_undirected=True) # Convert the graph to networkx format
plt.figure(figsize=(20,15))
plt.title('Largest connected component',fontsize=20)
pos = nx.spring_layout(A,seed=12)
#Let's drow the graph, adding borders to the nodes
'''
    Arguments of nx.draw:
        * G: The graph to draw.
        * node_color: The color of the nodes.
        * pos: A dictionary with nodes as keys and positions as values.
        * cmap: A colormap or registered colormap name.
        * node_size: The size of the nodes.
        * edge_color: The color of the edges.
        * width: The width of the edges.
        * with_labels: Whether to draw the node labels.
        * node_shape: The shape of the nodes.
        * alpha: The node transparency.
    Returns:
        * None
'''
nx.draw(A,node_color=data.y,pos= pos, cmap=plt.cm.viridis, node_size=100, edge_color='black',width=1,with_labels=False,node_shape='o',alpha=0.8)
plt.show()
# Out:
# Data(x=[127, 1703], edge_index=[2, 315], y=[127], train_mask=[183, 10], val_mask=[183, 10], test_mask=[183, 10], num_nodes=127, num_edges=159)

# %% [markdown]
# ### 1.3 Visualize full graph [Optional]

# %%
# The same as above but with the whole graph
data = dataset[0]
G = to_networkx(data, to_undirected=True)
plt.figure(figsize=(20,15))
plt.title('Whole graph',fontsize=20)
color = data.y
pos = nx.spring_layout(G,seed=12)
nx.draw(G,node_color=color,pos= pos, cmap=plt.cm.viridis, node_size=100, edge_color='black',width=1,with_labels=False,node_shape='o',alpha=0.8)
plt.show()

# %% [markdown]
# ### 2. Train a GCN model

# %% [markdown]
# In this section, we will train a GCN model to classify the nodes in the graph. We will use the node features as input to the model and the node labels as the target. Now let's create functions to train and evaluate the model.

# %% [markdown]
# #### Utility functions

# %%
''' 
    Arguments of train:
        * model: The model to train.
        * data: The data object.
        * optimizer: The optimizer to use.
        * train_mask: The mask of the training nodes.
        * criterion: The loss function to use.
    Returns:
        * loss: The loss of the model.
        * acc: The accuracy of the model.
'''
def train(model, data, optimizer,train_mask,device,criterion = torch.nn.CrossEntropyLoss()):
    model.train()
    optimizer.zero_grad() # Clear gradients.
    #Make sure that we only use the features of the training nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1])
    features[train_mask] = data.x[train_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    out = model(data.x, data.edge_index) # Perform a single forward pass.
    loss = criterion(out[train_mask], data.y[train_mask]) # Compute the loss solely based on the training nodes.
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[train_mask].eq(data.y[train_mask]).sum().item() / train_mask.sum().item() # Derive ratio of correct predictions.
    loss.backward() # Derive gradients.
    optimizer.step() # Update parameters based on gradients.
    return loss,acc
''' 
    Arguments of validation:
        * model: The model to train.
        * data: The data object.
        * val_mask: The mask of the validation nodes.
    Returns:
        * acc: The accuracy of the model.
'''
def validation(model,data,val_mask,device):
    model.eval() # Set model to evaluation mode (e.g. disable dropout)
    #Make sure that we only use the features of the validation nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1])
    features[val_mask] = data.x[val_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    out = model(data.x, data.edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[val_mask].eq(data.y[val_mask]).sum().item() / val_mask.sum().item() # Derive ratio of correct predictions.
    return acc
''' 
    Arguments of test:
        * model: The model to train.
        * data: The data object.
        * test_mask: The mask of the test nodes.
    Returns:
        * acc: The accuracy of the model.
'''
def test(model,data,test_mask,device):
    model.eval() # Set model to evaluation mode (e.g. disable dropout)
    #Make sure that we only use the features of the testing nodes
    features = torch.zeros(data.x.shape[0],data.x.shape[1])
    features[test_mask] = data.x[test_mask]
    # Put the features in the same device as the model
    features = features.to(device)
    out = model(data.x, data.edge_index)
    pred = out.argmax(dim=1) # Use the class with highest probability.
    acc = pred[test_mask].eq(data.y[test_mask]).sum().item() / test_mask.sum().item() # Derive ratio of correct predictions.
    return acc

# %% [markdown]
# #### Split dataset

# %% [markdown]
# In this section we will split the dataset into training, validation and test sets. We will use the training set to train the model, the validation set to tune the hyperparameters and the test set to evaluate the model. We will use two functions for the splits. One function will give as a semi-supervised split where we will have a small number of labeled nodes in the training set and the rest of the nodes will be unlabeled. The other function will give us a fully supervised split where all the nodes in the training set will be labeled.

# %%
from sklearn.model_selection import train_test_split
''' 
    Arguments of get_semi_supervised_split:
        * data: The data object.
        * seed: The seed to use for the random split.
    Returns: the train, test and validation masks with an 48%/32%/20%.
        * train_mask: The mask of the training nodes.
        * test_mask: The mask of the test nodes.
        * val_mask: The mask of the validation nodes.
'''
def get_semi_supervised_split(data,seed):
    #We are going to use 48% of the nodes for training, 32% for testing and 20% for validation
    #First we split the nodes in 80% for training and 20% for testing
    #Then we split the training nodes in 48% for training and 32% for validation over the 80% of the nodes
    train_split, test_split = train_test_split(list(range(len(data.y))), test_size=0.20,random_state=seed, shuffle=True)
    train_split, val_split = train_test_split(train_split, test_size=0.40,random_state=seed, shuffle=True)
    
    train_mask = torch.full_like(data.y, False, dtype=bool)
    train_mask[train_split] = True
    
    test_mask = torch.full_like(data.y, False, dtype=bool)
    test_mask[test_split] = True
    
    val_mask = torch.full_like(data.y, False, dtype=bool)
    val_mask[val_split] = True
    
    return train_mask,test_mask,val_mask
''' 
    Arguments of get_supervised_split:
        * data: The data object.
        * seed: The seed to use for the random split.
    Returns: the train, test and validation masks with an 60%/20%/20%.
        * train_mask: The mask of the training nodes.
        * test_mask: The mask of the test nodes.
        * val_mask: The mask of the validation nodes.
'''
def get_supervised_split(data,seed):
    train_split, test_split = train_test_split(list(range(len(data.y))), test_size=0.40,random_state=seed, shuffle=True)
    test_split, val_split = train_test_split(test_split, test_size=0.50,random_state=seed, shuffle=True)
    
    train_mask = torch.full_like(data.y, False, dtype=bool)
    train_mask[train_split] = True
    
    test_mask = torch.full_like(data.y, False, dtype=bool)
    test_mask[test_split] = True
    
    val_mask = torch.full_like(data.y, False, dtype=bool)
    val_mask[val_split] = True
      
    return train_mask, test_mask, val_mask

# %% [markdown]
# #### Create the model

# %% [markdown]
# In this section we will create our model for node classification. We will use a GCN model with 2 hidden layers. The input to the model will be the node features and the output will be the logits for each node in the graph. We will use the cross entropy loss function and the Adam optimizer.

# %%
from torch_geometric.nn import GCNConv
from torch.functional import F
'''
    In PyTorch, you define a model by subclassing torch.nn.Module and defining a forward() method which receives input data and returns output data.
    The forward() method can use other modules defined in the constructor as submodules, and it can use arbitrary operators on Tensors, including loops and conditional statements.
    This approach is very flexible, and you can use it to define models of arbitrary complexity.
'''
class GCN(torch.nn.Module):
    '''
        Arguments of __init__:
            * hidden_channels: The number of hidden units.
            * dataset.num_features: The number of input features.
            * dataset.num_classes: The number of output classes.
        Returns:
            * self.conv1: The first GCN layer.
            * self.conv2: The second GCN layer.
    '''
    def __init__(self,hidden_channels = 16):
        super(GCN, self).__init__()
        # 2-layer GCN
        self.conv1 = GCNConv(dataset.num_features, hidden_channels) # 32 hidden units
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes) # dataset.num_classes output units
    '''
        Arguments of forward:
            * x: The input features.
            * edge_index: The edge indices.
        Returns:
            * F.softmax(x, dim=1): The output of the model.
    '''
    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index)) # ReLU activation
        x = F.dropout(x,p=0.5, training=self.training) # Dropout: 50% of the nodes are randomly dropped out during training
        x = self.conv2(x, edge_index)
        return x.softmax(dim=1) # Log softmax activation
print(GCN())
# Out:
# GCN(
#   (conv1): GCNConv(1703, 16)
#   (conv2): GCNConv(16, 5)
# )

# %%
from torch.nn import Linear
# Same as GCN but with Linear layers instead of GCNConv layers. If we use MLP as a model, we can't take into account the graph STRUCTURE.
class MLP(torch.nn.Module):
    def __init__(self,hidden_channels = 16):
        super(MLP, self).__init__()
        # 2-layer GCN
        self.lin1 = Linear(dataset.num_features, hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index):
        # edge_index is not used
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x.softmax(dim=1)
print(MLP())
# Out:
# MLP(
#   (lin1): Linear(in_features=1703, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=5, bias=True)
# )

# %% [markdown]
# #### Train the model

# %%
# Seeds for the random split. This allows us to reproduce the results.
RandList = [12345, 423456, 643451, 543452, 743456, 4734510, 654321, 124321, 945321, 784328]
# This allows us to run the code on the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Here you can add models to train and test
models = [GCN(), MLP()]
global_results = []
global_best_models = []
for j in range(len(models)):
    ExperimentResult = []
    best_model = None
    print(data)
    for i in range(10):
        print("Random State", RandList[i]," in the iteration",i)
        train_mask,test_mask,val_mask = get_semi_supervised_split(data.cpu(), RandList[i])
        #train_mask,test_mask,val_mask = get_supervised_split(data.cpu(), RandList[i])
        data = data.to(device)
        model = models[j].to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
        for epoch in range(1, 101):
            loss, acc_train = train(model,data,optimizer,train_mask.to(device),device=device)
            acc_validation = validation(model,data,val_mask.to(device),device=device)
            print('Epoch: {:03d}, Loss: {:.5f}, Train Acc: {:.5f}, Val Acc: {:.5f}'.format(epoch, loss, acc_train, acc_validation))
        acc = test(model,data,test_mask.to(device),device=device)
        print('Test Accuracy: {:.5f}'.format(acc))
        # Save the best model over the 10 runs
        if best_model is None or acc > best_model[1]:
            best_model = [model, acc]
        ExperimentResult.append(acc)
    print(models[j].__class__.__name__) # Name of the model
    print('{} +- {}'.format(np.mean(ExperimentResult)*100, np.std(ExperimentResult)*100))
    global_results.append(ExperimentResult.copy())
    global_best_models.append(best_model.copy())
# Out:
# cpu
# Data(x=[183, 1703], edge_index=[2, 298], y=[183], train_mask=[183, 10], val_mask=[183, 10], test_mask=[183, 10])
# Random State 12345  in the iteration 0
# Epoch: 001, Loss: 1.57093, Train Acc: 0.40230, Val Acc: 0.45763
# Epoch: 002, Loss: 1.48678, Train Acc: 0.41379, Val Acc: 0.45763
# Epoch: 003, Loss: 1.44707, Train Acc: 0.44828, Val Acc: 0.45763
# Epoch: 004, Loss: 1.43537, Train Acc: 0.42529, Val Acc: 0.45763
# Epoch: 005, Loss: 1.39521, Train Acc: 0.48276, Val Acc: 0.45763
# Epoch: 006, Loss: 1.42163, Train Acc: 0.47126, Val Acc: 0.44068
# Epoch: 007, Loss: 1.33960, Train Acc: 0.57471, Val Acc: 0.42373
# Epoch: 008, Loss: 1.34102, Train Acc: 0.57471, Val Acc: 0.42373
# Epoch: 009, Loss: 1.33931, Train Acc: 0.58621, Val Acc: 0.44068
# Epoch: 010, Loss: 1.33921, Train Acc: 0.58621, Val Acc: 0.44068
# Epoch: 011, Loss: 1.32118, Train Acc: 0.59770, Val Acc: 0.40678
# Epoch: 012, Loss: 1.28726, Train Acc: 0.63218, Val Acc: 0.40678
# Epoch: 013, Loss: 1.29891, Train Acc: 0.62069, Val Acc: 0.42373
# Epoch: 014, Loss: 1.31600, Train Acc: 0.63218, Val Acc: 0.42373
# Epoch: 015, Loss: 1.27731, Train Acc: 0.66667, Val Acc: 0.44068
# Epoch: 016, Loss: 1.27203, Train Acc: 0.67816, Val Acc: 0.44068
# Epoch: 017, Loss: 1.25987, Train Acc: 0.66667, Val Acc: 0.40678
# Epoch: 018, Loss: 1.27319, Train Acc: 0.68966, Val Acc: 0.40678
# Epoch: 019, Loss: 1.26610, Train Acc: 0.66667, Val Acc: 0.40678
# Epoch: 020, Loss: 1.25562, Train Acc: 0.66667, Val Acc: 0.38983
# Epoch: 021, Loss: 1.25546, Train Acc: 0.66667, Val Acc: 0.38983
# Epoch: 022, Loss: 1.29093, Train Acc: 0.65517, Val Acc: 0.38983
# Epoch: 023, Loss: 1.24398, Train Acc: 0.68966, Val Acc: 0.38983
# Epoch: 024, Loss: 1.27916, Train Acc: 0.66667, Val Acc: 0.38983
# Epoch: 025, Loss: 1.28093, Train Acc: 0.65517, Val Acc: 0.38983
# Epoch: 026, Loss: 1.27581, Train Acc: 0.65517, Val Acc: 0.38983
# Epoch: 027, Loss: 1.24368, Train Acc: 0.67816, Val Acc: 0.38983
# Epoch: 028, Loss: 1.25131, Train Acc: 0.67816, Val Acc: 0.38983
# Epoch: 029, Loss: 1.24073, Train Acc: 0.70115, Val Acc: 0.37288
# Epoch: 030, Loss: 1.24473, Train Acc: 0.67816, Val Acc: 0.37288
# Epoch: 031, Loss: 1.28551, Train Acc: 0.60920, Val Acc: 0.37288
# Epoch: 032, Loss: 1.25717, Train Acc: 0.67816, Val Acc: 0.37288
# Epoch: 033, Loss: 1.24917, Train Acc: 0.64368, Val Acc: 0.37288
# Epoch: 034, Loss: 1.24627, Train Acc: 0.66667, Val Acc: 0.37288
# Epoch: 035, Loss: 1.22394, Train Acc: 0.71264, Val Acc: 0.37288
# Epoch: 036, Loss: 1.25789, Train Acc: 0.66667, Val Acc: 0.38983
# Epoch: 037, Loss: 1.24450, Train Acc: 0.67816, Val Acc: 0.38983
# Epoch: 038, Loss: 1.23702, Train Acc: 0.67816, Val Acc: 0.38983
# Epoch: 039, Loss: 1.27169, Train Acc: 0.64368, Val Acc: 0.40678
# Epoch: 040, Loss: 1.24659, Train Acc: 0.68966, Val Acc: 0.40678
# Epoch: 041, Loss: 1.23881, Train Acc: 0.67816, Val Acc: 0.40678
# Epoch: 042, Loss: 1.26059, Train Acc: 0.66667, Val Acc: 0.40678
# Epoch: 043, Loss: 1.23288, Train Acc: 0.67816, Val Acc: 0.38983
# Epoch: 044, Loss: 1.24500, Train Acc: 0.66667, Val Acc: 0.38983
# Epoch: 045, Loss: 1.23078, Train Acc: 0.67816, Val Acc: 0.38983
# Epoch: 046, Loss: 1.23627, Train Acc: 0.68966, Val Acc: 0.37288
# Epoch: 047, Loss: 1.19763, Train Acc: 0.72414, Val Acc: 0.35593
# Epoch: 048, Loss: 1.24370, Train Acc: 0.70115, Val Acc: 0.33898
# Epoch: 049, Loss: 1.21470, Train Acc: 0.71264, Val Acc: 0.37288
# Epoch: 050, Loss: 1.21348, Train Acc: 0.71264, Val Acc: 0.37288
# Epoch: 051, Loss: 1.24085, Train Acc: 0.70115, Val Acc: 0.40678
# Epoch: 052, Loss: 1.22550, Train Acc: 0.68966, Val Acc: 0.40678
# Epoch: 053, Loss: 1.22826, Train Acc: 0.67816, Val Acc: 0.40678
# Epoch: 054, Loss: 1.25018, Train Acc: 0.66667, Val Acc: 0.40678
# Epoch: 055, Loss: 1.21254, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 056, Loss: 1.21100, Train Acc: 0.70115, Val Acc: 0.38983
# Epoch: 057, Loss: 1.21628, Train Acc: 0.72414, Val Acc: 0.38983
# Epoch: 058, Loss: 1.21344, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 059, Loss: 1.21557, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 060, Loss: 1.23793, Train Acc: 0.68966, Val Acc: 0.40678
# Epoch: 061, Loss: 1.20924, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 062, Loss: 1.22450, Train Acc: 0.67816, Val Acc: 0.40678
# Epoch: 063, Loss: 1.20382, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 064, Loss: 1.21348, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 065, Loss: 1.24533, Train Acc: 0.65517, Val Acc: 0.40678
# Epoch: 066, Loss: 1.21140, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 067, Loss: 1.22476, Train Acc: 0.70115, Val Acc: 0.40678
# Epoch: 068, Loss: 1.19750, Train Acc: 0.73563, Val Acc: 0.40678
# Epoch: 069, Loss: 1.22607, Train Acc: 0.70115, Val Acc: 0.40678
# Epoch: 070, Loss: 1.20366, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 071, Loss: 1.22303, Train Acc: 0.70115, Val Acc: 0.40678
# Epoch: 072, Loss: 1.20048, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 073, Loss: 1.21486, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 074, Loss: 1.20613, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 075, Loss: 1.21458, Train Acc: 0.70115, Val Acc: 0.42373
# Epoch: 076, Loss: 1.21160, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 077, Loss: 1.18665, Train Acc: 0.73563, Val Acc: 0.42373
# Epoch: 078, Loss: 1.20792, Train Acc: 0.71264, Val Acc: 0.42373
# Epoch: 079, Loss: 1.18952, Train Acc: 0.73563, Val Acc: 0.42373
# Epoch: 080, Loss: 1.21602, Train Acc: 0.72414, Val Acc: 0.42373
# Epoch: 081, Loss: 1.21679, Train Acc: 0.70115, Val Acc: 0.42373
# Epoch: 082, Loss: 1.19348, Train Acc: 0.72414, Val Acc: 0.42373
# Epoch: 083, Loss: 1.21590, Train Acc: 0.68966, Val Acc: 0.42373
# Epoch: 084, Loss: 1.26420, Train Acc: 0.65517, Val Acc: 0.42373
# Epoch: 085, Loss: 1.19908, Train Acc: 0.71264, Val Acc: 0.44068
# Epoch: 086, Loss: 1.19387, Train Acc: 0.72414, Val Acc: 0.44068
# Epoch: 087, Loss: 1.22030, Train Acc: 0.68966, Val Acc: 0.42373
# Epoch: 088, Loss: 1.20780, Train Acc: 0.72414, Val Acc: 0.42373
# Epoch: 089, Loss: 1.19464, Train Acc: 0.73563, Val Acc: 0.42373
# Epoch: 090, Loss: 1.20614, Train Acc: 0.71264, Val Acc: 0.42373
# Epoch: 091, Loss: 1.20427, Train Acc: 0.70115, Val Acc: 0.42373
# Epoch: 092, Loss: 1.20743, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 093, Loss: 1.22152, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 094, Loss: 1.20464, Train Acc: 0.73563, Val Acc: 0.42373
# Epoch: 095, Loss: 1.21302, Train Acc: 0.70115, Val Acc: 0.42373
# Epoch: 096, Loss: 1.21438, Train Acc: 0.68966, Val Acc: 0.42373
# Epoch: 097, Loss: 1.20646, Train Acc: 0.71264, Val Acc: 0.42373
# Epoch: 098, Loss: 1.21033, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 099, Loss: 1.20948, Train Acc: 0.73563, Val Acc: 0.40678
# Epoch: 100, Loss: 1.18899, Train Acc: 0.73563, Val Acc: 0.38983
# Test Accuracy: 0.54054
# Random State 423456  in the iteration 1
# Epoch: 001, Loss: 1.30983, Train Acc: 0.59770, Val Acc: 0.52542
# Epoch: 002, Loss: 1.28387, Train Acc: 0.63218, Val Acc: 0.54237
# Epoch: 003, Loss: 1.27046, Train Acc: 0.64368, Val Acc: 0.55932
# Epoch: 004, Loss: 1.26747, Train Acc: 0.64368, Val Acc: 0.50847
# Epoch: 005, Loss: 1.25829, Train Acc: 0.64368, Val Acc: 0.50847
# Epoch: 006, Loss: 1.27010, Train Acc: 0.64368, Val Acc: 0.50847
# Epoch: 007, Loss: 1.30423, Train Acc: 0.59770, Val Acc: 0.49153
# Epoch: 008, Loss: 1.25587, Train Acc: 0.65517, Val Acc: 0.47458
# Epoch: 009, Loss: 1.23757, Train Acc: 0.67816, Val Acc: 0.45763
# Epoch: 010, Loss: 1.23621, Train Acc: 0.66667, Val Acc: 0.44068
# Epoch: 011, Loss: 1.24865, Train Acc: 0.66667, Val Acc: 0.44068
# Epoch: 012, Loss: 1.21461, Train Acc: 0.68966, Val Acc: 0.44068
# Epoch: 013, Loss: 1.23311, Train Acc: 0.67816, Val Acc: 0.44068
# Epoch: 014, Loss: 1.22793, Train Acc: 0.67816, Val Acc: 0.44068
# Epoch: 015, Loss: 1.31204, Train Acc: 0.58621, Val Acc: 0.44068
# Epoch: 016, Loss: 1.25471, Train Acc: 0.65517, Val Acc: 0.44068
# Epoch: 017, Loss: 1.23317, Train Acc: 0.67816, Val Acc: 0.47458
# Epoch: 018, Loss: 1.23821, Train Acc: 0.66667, Val Acc: 0.45763
# Epoch: 019, Loss: 1.22838, Train Acc: 0.67816, Val Acc: 0.45763
# Epoch: 020, Loss: 1.24147, Train Acc: 0.65517, Val Acc: 0.47458
# Epoch: 021, Loss: 1.21123, Train Acc: 0.68966, Val Acc: 0.45763
# Epoch: 022, Loss: 1.22468, Train Acc: 0.67816, Val Acc: 0.45763
# Epoch: 023, Loss: 1.20423, Train Acc: 0.71264, Val Acc: 0.45763
# Epoch: 024, Loss: 1.23703, Train Acc: 0.66667, Val Acc: 0.44068
# Epoch: 025, Loss: 1.20910, Train Acc: 0.70115, Val Acc: 0.44068
# Epoch: 026, Loss: 1.21825, Train Acc: 0.68966, Val Acc: 0.44068
# Epoch: 027, Loss: 1.21281, Train Acc: 0.68966, Val Acc: 0.44068
# Epoch: 028, Loss: 1.23439, Train Acc: 0.68966, Val Acc: 0.44068
# Epoch: 029, Loss: 1.20923, Train Acc: 0.70115, Val Acc: 0.44068
# Epoch: 030, Loss: 1.26400, Train Acc: 0.66667, Val Acc: 0.42373
# Epoch: 031, Loss: 1.20215, Train Acc: 0.70115, Val Acc: 0.40678
# Epoch: 032, Loss: 1.19601, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 033, Loss: 1.19725, Train Acc: 0.70115, Val Acc: 0.40678
# Epoch: 034, Loss: 1.19702, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 035, Loss: 1.19873, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 036, Loss: 1.20834, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 037, Loss: 1.18871, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 038, Loss: 1.24888, Train Acc: 0.63218, Val Acc: 0.40678
# Epoch: 039, Loss: 1.19885, Train Acc: 0.72414, Val Acc: 0.38983
# Epoch: 040, Loss: 1.18782, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 041, Loss: 1.19698, Train Acc: 0.72414, Val Acc: 0.44068
# Epoch: 042, Loss: 1.19399, Train Acc: 0.72414, Val Acc: 0.42373
# Epoch: 043, Loss: 1.17953, Train Acc: 0.73563, Val Acc: 0.42373
# Epoch: 044, Loss: 1.21054, Train Acc: 0.70115, Val Acc: 0.42373
# Epoch: 045, Loss: 1.19573, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 046, Loss: 1.19529, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 047, Loss: 1.18306, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 048, Loss: 1.19534, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 049, Loss: 1.21987, Train Acc: 0.68966, Val Acc: 0.40678
# Epoch: 050, Loss: 1.19854, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 051, Loss: 1.18218, Train Acc: 0.73563, Val Acc: 0.40678
# Epoch: 052, Loss: 1.18924, Train Acc: 0.71264, Val Acc: 0.38983
# Epoch: 053, Loss: 1.19141, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 054, Loss: 1.17658, Train Acc: 0.73563, Val Acc: 0.40678
# Epoch: 055, Loss: 1.20206, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 056, Loss: 1.19820, Train Acc: 0.70115, Val Acc: 0.38983
# Epoch: 057, Loss: 1.18044, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 058, Loss: 1.17851, Train Acc: 0.73563, Val Acc: 0.40678
# Epoch: 059, Loss: 1.19933, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 060, Loss: 1.17359, Train Acc: 0.73563, Val Acc: 0.40678
# Epoch: 061, Loss: 1.20504, Train Acc: 0.70115, Val Acc: 0.40678
# Epoch: 062, Loss: 1.18354, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 063, Loss: 1.17822, Train Acc: 0.73563, Val Acc: 0.40678
# Epoch: 064, Loss: 1.20263, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 065, Loss: 1.19329, Train Acc: 0.73563, Val Acc: 0.40678
# Epoch: 066, Loss: 1.19239, Train Acc: 0.71264, Val Acc: 0.40678
# Epoch: 067, Loss: 1.17264, Train Acc: 0.73563, Val Acc: 0.38983
# Epoch: 068, Loss: 1.16228, Train Acc: 0.74713, Val Acc: 0.38983
# Epoch: 069, Loss: 1.17936, Train Acc: 0.73563, Val Acc: 0.38983
# Epoch: 070, Loss: 1.19110, Train Acc: 0.72414, Val Acc: 0.38983
# Epoch: 071, Loss: 1.18504, Train Acc: 0.72414, Val Acc: 0.38983
# Epoch: 072, Loss: 1.19068, Train Acc: 0.72414, Val Acc: 0.40678
# Epoch: 073, Loss: 1.17056, Train Acc: 0.74713, Val Acc: 0.38983
# Epoch: 074, Loss: 1.17145, Train Acc: 0.73563, Val Acc: 0.38983
# Epoch: 075, Loss: 1.15856, Train Acc: 0.77011, Val Acc: 0.37288
# Epoch: 076, Loss: 1.17268, Train Acc: 0.73563, Val Acc: 0.38983
# Epoch: 077, Loss: 1.15296, Train Acc: 0.77011, Val Acc: 0.38983
# Epoch: 078, Loss: 1.17990, Train Acc: 0.72414, Val Acc: 0.38983
# Epoch: 079, Loss: 1.14250, Train Acc: 0.78161, Val Acc: 0.38983
# Epoch: 080, Loss: 1.18413, Train Acc: 0.72414, Val Acc: 0.37288
# Epoch: 081, Loss: 1.21699, Train Acc: 0.67816, Val Acc: 0.37288
# Epoch: 082, Loss: 1.14961, Train Acc: 0.75862, Val Acc: 0.38983
# Epoch: 083, Loss: 1.17405, Train Acc: 0.74713, Val Acc: 0.38983
# Epoch: 084, Loss: 1.17599, Train Acc: 0.73563, Val Acc: 0.38983
# Epoch: 085, Loss: 1.18106, Train Acc: 0.73563, Val Acc: 0.38983
# Epoch: 086, Loss: 1.17034, Train Acc: 0.74713, Val Acc: 0.38983
# Epoch: 087, Loss: 1.17180, Train Acc: 0.74713, Val Acc: 0.37288
# Epoch: 088, Loss: 1.18749, Train Acc: 0.72414, Val Acc: 0.35593
# Epoch: 089, Loss: 1.16613, Train Acc: 0.73563, Val Acc: 0.35593
# Epoch: 090, Loss: 1.17186, Train Acc: 0.73563, Val Acc: 0.35593
# Epoch: 091, Loss: 1.14509, Train Acc: 0.74713, Val Acc: 0.35593
# Epoch: 092, Loss: 1.18621, Train Acc: 0.72414, Val Acc: 0.35593
# Epoch: 093, Loss: 1.17646, Train Acc: 0.73563, Val Acc: 0.37288
# Epoch: 094, Loss: 1.19060, Train Acc: 0.71264, Val Acc: 0.35593
# Epoch: 095, Loss: 1.19364, Train Acc: 0.70115, Val Acc: 0.37288
# Epoch: 096, Loss: 1.17344, Train Acc: 0.72414, Val Acc: 0.37288
# Epoch: 097, Loss: 1.15128, Train Acc: 0.74713, Val Acc: 0.37288
# Epoch: 098, Loss: 1.12428, Train Acc: 0.79310, Val Acc: 0.35593
# Epoch: 099, Loss: 1.14070, Train Acc: 0.78161, Val Acc: 0.37288
# Epoch: 100, Loss: 1.11342, Train Acc: 0.79310, Val Acc: 0.38983
# Test Accuracy: 0.37838
# Random State 643451  in the iteration 2
# Epoch: 001, Loss: 1.31718, Train Acc: 0.59770, Val Acc: 0.66102
# Epoch: 002, Loss: 1.34149, Train Acc: 0.56322, Val Acc: 0.67797
# Epoch: 003, Loss: 1.28550, Train Acc: 0.60920, Val Acc: 0.67797
# Epoch: 004, Loss: 1.24957, Train Acc: 0.65517, Val Acc: 0.62712
# Epoch: 005, Loss: 1.29497, Train Acc: 0.60920, Val Acc: 0.57627
# Epoch: 006, Loss: 1.23919, Train Acc: 0.65517, Val Acc: 0.57627
# Epoch: 007, Loss: 1.26272, Train Acc: 0.64368, Val Acc: 0.55932
# Epoch: 008, Loss: 1.26675, Train Acc: 0.63218, Val Acc: 0.55932
# Epoch: 009, Loss: 1.22790, Train Acc: 0.66667, Val Acc: 0.54237
# Epoch: 010, Loss: 1.25325, Train Acc: 0.64368, Val Acc: 0.61017
# Epoch: 011, Loss: 1.23084, Train Acc: 0.67816, Val Acc: 0.62712
# Epoch: 012, Loss: 1.19954, Train Acc: 0.70115, Val Acc: 0.62712
# Epoch: 013, Loss: 1.22893, Train Acc: 0.68966, Val Acc: 0.61017
# Epoch: 014, Loss: 1.20062, Train Acc: 0.71264, Val Acc: 0.61017
# Epoch: 015, Loss: 1.19107, Train Acc: 0.74713, Val Acc: 0.61017
# Epoch: 016, Loss: 1.21572, Train Acc: 0.68966, Val Acc: 0.61017
# Epoch: 017, Loss: 1.18415, Train Acc: 0.73563, Val Acc: 0.62712
# Epoch: 018, Loss: 1.20191, Train Acc: 0.71264, Val Acc: 0.62712
# Epoch: 019, Loss: 1.15744, Train Acc: 0.75862, Val Acc: 0.61017
# Epoch: 020, Loss: 1.17133, Train Acc: 0.74713, Val Acc: 0.62712
# Epoch: 021, Loss: 1.15864, Train Acc: 0.74713, Val Acc: 0.62712
# Epoch: 022, Loss: 1.16322, Train Acc: 0.74713, Val Acc: 0.62712
# Epoch: 023, Loss: 1.19007, Train Acc: 0.74713, Val Acc: 0.62712
# Epoch: 024, Loss: 1.16679, Train Acc: 0.74713, Val Acc: 0.61017
# Epoch: 025, Loss: 1.18254, Train Acc: 0.72414, Val Acc: 0.59322
# Epoch: 026, Loss: 1.15333, Train Acc: 0.74713, Val Acc: 0.57627
# Epoch: 027, Loss: 1.15650, Train Acc: 0.73563, Val Acc: 0.55932
# Epoch: 028, Loss: 1.16397, Train Acc: 0.77011, Val Acc: 0.55932
# Epoch: 029, Loss: 1.17032, Train Acc: 0.77011, Val Acc: 0.55932
# Epoch: 030, Loss: 1.13676, Train Acc: 0.77011, Val Acc: 0.55932
# Epoch: 031, Loss: 1.13838, Train Acc: 0.77011, Val Acc: 0.54237
# Epoch: 032, Loss: 1.14192, Train Acc: 0.78161, Val Acc: 0.54237
# Epoch: 033, Loss: 1.15094, Train Acc: 0.74713, Val Acc: 0.54237
# Epoch: 034, Loss: 1.17137, Train Acc: 0.73563, Val Acc: 0.54237
# Epoch: 035, Loss: 1.16167, Train Acc: 0.75862, Val Acc: 0.54237
# Epoch: 036, Loss: 1.12056, Train Acc: 0.79310, Val Acc: 0.54237
# Epoch: 037, Loss: 1.13760, Train Acc: 0.78161, Val Acc: 0.55932
# Epoch: 038, Loss: 1.14214, Train Acc: 0.78161, Val Acc: 0.54237
# Epoch: 039, Loss: 1.13372, Train Acc: 0.79310, Val Acc: 0.55932
# Epoch: 040, Loss: 1.15023, Train Acc: 0.77011, Val Acc: 0.57627
# Epoch: 041, Loss: 1.12416, Train Acc: 0.78161, Val Acc: 0.59322
# Epoch: 042, Loss: 1.16429, Train Acc: 0.74713, Val Acc: 0.57627
# Epoch: 043, Loss: 1.15235, Train Acc: 0.77011, Val Acc: 0.55932
# Epoch: 044, Loss: 1.12160, Train Acc: 0.77011, Val Acc: 0.55932
# Epoch: 045, Loss: 1.14886, Train Acc: 0.75862, Val Acc: 0.54237
# Epoch: 046, Loss: 1.13421, Train Acc: 0.78161, Val Acc: 0.54237
# Epoch: 047, Loss: 1.12695, Train Acc: 0.77011, Val Acc: 0.50847
# Epoch: 048, Loss: 1.16837, Train Acc: 0.72414, Val Acc: 0.50847
# Epoch: 049, Loss: 1.17229, Train Acc: 0.75862, Val Acc: 0.54237
# Epoch: 050, Loss: 1.11536, Train Acc: 0.81609, Val Acc: 0.52542
# Epoch: 051, Loss: 1.15636, Train Acc: 0.74713, Val Acc: 0.52542
# Epoch: 052, Loss: 1.14799, Train Acc: 0.77011, Val Acc: 0.54237
# Epoch: 053, Loss: 1.12403, Train Acc: 0.78161, Val Acc: 0.55932
# Epoch: 054, Loss: 1.17515, Train Acc: 0.74713, Val Acc: 0.54237
# Epoch: 055, Loss: 1.10281, Train Acc: 0.82759, Val Acc: 0.57627
# Epoch: 056, Loss: 1.12181, Train Acc: 0.79310, Val Acc: 0.57627
# Epoch: 057, Loss: 1.13183, Train Acc: 0.74713, Val Acc: 0.57627
# Epoch: 058, Loss: 1.10696, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 059, Loss: 1.13802, Train Acc: 0.78161, Val Acc: 0.54237
# Epoch: 060, Loss: 1.11406, Train Acc: 0.79310, Val Acc: 0.54237
# Epoch: 061, Loss: 1.11057, Train Acc: 0.80460, Val Acc: 0.54237
# Epoch: 062, Loss: 1.10734, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 063, Loss: 1.10506, Train Acc: 0.80460, Val Acc: 0.54237
# Epoch: 064, Loss: 1.10318, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 065, Loss: 1.11586, Train Acc: 0.79310, Val Acc: 0.54237
# Epoch: 066, Loss: 1.08354, Train Acc: 0.82759, Val Acc: 0.55932
# Epoch: 067, Loss: 1.11599, Train Acc: 0.79310, Val Acc: 0.55932
# Epoch: 068, Loss: 1.09554, Train Acc: 0.80460, Val Acc: 0.55932
# Epoch: 069, Loss: 1.10783, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 070, Loss: 1.10044, Train Acc: 0.81609, Val Acc: 0.52542
# Epoch: 071, Loss: 1.13557, Train Acc: 0.79310, Val Acc: 0.52542
# Epoch: 072, Loss: 1.08637, Train Acc: 0.82759, Val Acc: 0.52542
# Epoch: 073, Loss: 1.09969, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 074, Loss: 1.09800, Train Acc: 0.80460, Val Acc: 0.54237
# Epoch: 075, Loss: 1.10480, Train Acc: 0.80460, Val Acc: 0.54237
# Epoch: 076, Loss: 1.09386, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 077, Loss: 1.08209, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 078, Loss: 1.07143, Train Acc: 0.83908, Val Acc: 0.54237
# Epoch: 079, Loss: 1.07187, Train Acc: 0.87356, Val Acc: 0.54237
# Epoch: 080, Loss: 1.09405, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 081, Loss: 1.09330, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 082, Loss: 1.10410, Train Acc: 0.80460, Val Acc: 0.54237
# Epoch: 083, Loss: 1.11042, Train Acc: 0.78161, Val Acc: 0.52542
# Epoch: 084, Loss: 1.11024, Train Acc: 0.79310, Val Acc: 0.52542
# Epoch: 085, Loss: 1.07857, Train Acc: 0.82759, Val Acc: 0.52542
# Epoch: 086, Loss: 1.07181, Train Acc: 0.85057, Val Acc: 0.49153
# Epoch: 087, Loss: 1.11258, Train Acc: 0.79310, Val Acc: 0.49153
# Epoch: 088, Loss: 1.08035, Train Acc: 0.82759, Val Acc: 0.50847
# Epoch: 089, Loss: 1.09885, Train Acc: 0.82759, Val Acc: 0.50847
# Epoch: 090, Loss: 1.06886, Train Acc: 0.83908, Val Acc: 0.52542
# Epoch: 091, Loss: 1.10434, Train Acc: 0.81609, Val Acc: 0.52542
# Epoch: 092, Loss: 1.09356, Train Acc: 0.80460, Val Acc: 0.52542
# Epoch: 093, Loss: 1.08945, Train Acc: 0.82759, Val Acc: 0.52542
# Epoch: 094, Loss: 1.08960, Train Acc: 0.82759, Val Acc: 0.55932
# Epoch: 095, Loss: 1.09763, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 096, Loss: 1.07886, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 097, Loss: 1.09411, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 098, Loss: 1.10564, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 099, Loss: 1.11133, Train Acc: 0.80460, Val Acc: 0.55932
# Epoch: 100, Loss: 1.06211, Train Acc: 0.85057, Val Acc: 0.55932
# Test Accuracy: 0.54054
# Random State 543452  in the iteration 3
# Epoch: 001, Loss: 1.19901, Train Acc: 0.72414, Val Acc: 0.71186
# Epoch: 002, Loss: 1.17692, Train Acc: 0.74713, Val Acc: 0.69492
# Epoch: 003, Loss: 1.20343, Train Acc: 0.71264, Val Acc: 0.66102
# Epoch: 004, Loss: 1.12666, Train Acc: 0.78161, Val Acc: 0.67797
# Epoch: 005, Loss: 1.20777, Train Acc: 0.71264, Val Acc: 0.62712
# Epoch: 006, Loss: 1.19257, Train Acc: 0.71264, Val Acc: 0.61017
# Epoch: 007, Loss: 1.12987, Train Acc: 0.79310, Val Acc: 0.62712
# Epoch: 008, Loss: 1.16074, Train Acc: 0.75862, Val Acc: 0.62712
# Epoch: 009, Loss: 1.15837, Train Acc: 0.75862, Val Acc: 0.62712
# Epoch: 010, Loss: 1.15967, Train Acc: 0.75862, Val Acc: 0.64407
# Epoch: 011, Loss: 1.16478, Train Acc: 0.73563, Val Acc: 0.64407
# Epoch: 012, Loss: 1.14562, Train Acc: 0.74713, Val Acc: 0.62712
# Epoch: 013, Loss: 1.12551, Train Acc: 0.78161, Val Acc: 0.61017
# Epoch: 014, Loss: 1.11138, Train Acc: 0.80460, Val Acc: 0.61017
# Epoch: 015, Loss: 1.13195, Train Acc: 0.78161, Val Acc: 0.62712
# Epoch: 016, Loss: 1.15695, Train Acc: 0.75862, Val Acc: 0.66102
# Epoch: 017, Loss: 1.09986, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 018, Loss: 1.13955, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 019, Loss: 1.11658, Train Acc: 0.81609, Val Acc: 0.62712
# Epoch: 020, Loss: 1.13227, Train Acc: 0.77011, Val Acc: 0.61017
# Epoch: 021, Loss: 1.15724, Train Acc: 0.75862, Val Acc: 0.62712
# Epoch: 022, Loss: 1.12072, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 023, Loss: 1.09108, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 024, Loss: 1.11694, Train Acc: 0.79310, Val Acc: 0.67797
# Epoch: 025, Loss: 1.09335, Train Acc: 0.82759, Val Acc: 0.67797
# Epoch: 026, Loss: 1.11404, Train Acc: 0.79310, Val Acc: 0.66102
# Epoch: 027, Loss: 1.07813, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 028, Loss: 1.14772, Train Acc: 0.77011, Val Acc: 0.62712
# Epoch: 029, Loss: 1.15938, Train Acc: 0.75862, Val Acc: 0.62712
# Epoch: 030, Loss: 1.08370, Train Acc: 0.85057, Val Acc: 0.66102
# Epoch: 031, Loss: 1.10175, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 032, Loss: 1.13198, Train Acc: 0.77011, Val Acc: 0.66102
# Epoch: 033, Loss: 1.10399, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 034, Loss: 1.09403, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 035, Loss: 1.11094, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 036, Loss: 1.07155, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 037, Loss: 1.09874, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 038, Loss: 1.10226, Train Acc: 0.80460, Val Acc: 0.64407
# Epoch: 039, Loss: 1.08590, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 040, Loss: 1.08997, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 041, Loss: 1.06835, Train Acc: 0.86207, Val Acc: 0.66102
# Epoch: 042, Loss: 1.09813, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 043, Loss: 1.10139, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 044, Loss: 1.13367, Train Acc: 0.78161, Val Acc: 0.64407
# Epoch: 045, Loss: 1.06992, Train Acc: 0.83908, Val Acc: 0.62712
# Epoch: 046, Loss: 1.08105, Train Acc: 0.85057, Val Acc: 0.62712
# Epoch: 047, Loss: 1.10465, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 048, Loss: 1.07567, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 049, Loss: 1.06931, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 050, Loss: 1.07525, Train Acc: 0.85057, Val Acc: 0.62712
# Epoch: 051, Loss: 1.09317, Train Acc: 0.82759, Val Acc: 0.61017
# Epoch: 052, Loss: 1.10660, Train Acc: 0.78161, Val Acc: 0.57627
# Epoch: 053, Loss: 1.09762, Train Acc: 0.82759, Val Acc: 0.57627
# Epoch: 054, Loss: 1.05407, Train Acc: 0.88506, Val Acc: 0.57627
# Epoch: 055, Loss: 1.06435, Train Acc: 0.86207, Val Acc: 0.59322
# Epoch: 056, Loss: 1.08096, Train Acc: 0.85057, Val Acc: 0.59322
# Epoch: 057, Loss: 1.08112, Train Acc: 0.81609, Val Acc: 0.59322
# Epoch: 058, Loss: 1.08547, Train Acc: 0.83908, Val Acc: 0.61017
# Epoch: 059, Loss: 1.09577, Train Acc: 0.83908, Val Acc: 0.59322
# Epoch: 060, Loss: 1.05783, Train Acc: 0.86207, Val Acc: 0.59322
# Epoch: 061, Loss: 1.10794, Train Acc: 0.79310, Val Acc: 0.59322
# Epoch: 062, Loss: 1.10232, Train Acc: 0.82759, Val Acc: 0.59322
# Epoch: 063, Loss: 1.08130, Train Acc: 0.83908, Val Acc: 0.59322
# Epoch: 064, Loss: 1.07504, Train Acc: 0.83908, Val Acc: 0.59322
# Epoch: 065, Loss: 1.08481, Train Acc: 0.83908, Val Acc: 0.61017
# Epoch: 066, Loss: 1.10179, Train Acc: 0.81609, Val Acc: 0.62712
# Epoch: 067, Loss: 1.08284, Train Acc: 0.82759, Val Acc: 0.61017
# Epoch: 068, Loss: 1.10104, Train Acc: 0.81609, Val Acc: 0.62712
# Epoch: 069, Loss: 1.06091, Train Acc: 0.85057, Val Acc: 0.61017
# Epoch: 070, Loss: 1.08242, Train Acc: 0.81609, Val Acc: 0.61017
# Epoch: 071, Loss: 1.08405, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 072, Loss: 1.08881, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 073, Loss: 1.07904, Train Acc: 0.83908, Val Acc: 0.62712
# Epoch: 074, Loss: 1.09527, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 075, Loss: 1.08921, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 076, Loss: 1.09101, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 077, Loss: 1.08746, Train Acc: 0.82759, Val Acc: 0.62712
# Epoch: 078, Loss: 1.07575, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 079, Loss: 1.08218, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 080, Loss: 1.09683, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 081, Loss: 1.08320, Train Acc: 0.85057, Val Acc: 0.64407
# Epoch: 082, Loss: 1.09985, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 083, Loss: 1.06842, Train Acc: 0.85057, Val Acc: 0.64407
# Epoch: 084, Loss: 1.07591, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 085, Loss: 1.09813, Train Acc: 0.80460, Val Acc: 0.66102
# Epoch: 086, Loss: 1.07626, Train Acc: 0.85057, Val Acc: 0.66102
# Epoch: 087, Loss: 1.07496, Train Acc: 0.85057, Val Acc: 0.67797
# Epoch: 088, Loss: 1.05498, Train Acc: 0.87356, Val Acc: 0.67797
# Epoch: 089, Loss: 1.07686, Train Acc: 0.83908, Val Acc: 0.67797
# Epoch: 090, Loss: 1.06702, Train Acc: 0.86207, Val Acc: 0.66102
# Epoch: 091, Loss: 1.09275, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 092, Loss: 1.08189, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 093, Loss: 1.05484, Train Acc: 0.87356, Val Acc: 0.66102
# Epoch: 094, Loss: 1.07264, Train Acc: 0.86207, Val Acc: 0.62712
# Epoch: 095, Loss: 1.05200, Train Acc: 0.88506, Val Acc: 0.62712
# Epoch: 096, Loss: 1.07891, Train Acc: 0.81609, Val Acc: 0.62712
# Epoch: 097, Loss: 1.07789, Train Acc: 0.83908, Val Acc: 0.62712
# Epoch: 098, Loss: 1.07503, Train Acc: 0.85057, Val Acc: 0.64407
# Epoch: 099, Loss: 1.08020, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 100, Loss: 1.03304, Train Acc: 0.89655, Val Acc: 0.61017
# Test Accuracy: 0.37838
# Random State 743456  in the iteration 4
# Epoch: 001, Loss: 1.18154, Train Acc: 0.73563, Val Acc: 0.66102
# Epoch: 002, Loss: 1.18169, Train Acc: 0.72414, Val Acc: 0.64407
# Epoch: 003, Loss: 1.17594, Train Acc: 0.73563, Val Acc: 0.66102
# Epoch: 004, Loss: 1.17662, Train Acc: 0.71264, Val Acc: 0.66102
# Epoch: 005, Loss: 1.18180, Train Acc: 0.71264, Val Acc: 0.66102
# Epoch: 006, Loss: 1.15165, Train Acc: 0.73563, Val Acc: 0.66102
# Epoch: 007, Loss: 1.16379, Train Acc: 0.73563, Val Acc: 0.64407
# Epoch: 008, Loss: 1.13583, Train Acc: 0.77011, Val Acc: 0.64407
# Epoch: 009, Loss: 1.14531, Train Acc: 0.78161, Val Acc: 0.64407
# Epoch: 010, Loss: 1.11449, Train Acc: 0.80460, Val Acc: 0.62712
# Epoch: 011, Loss: 1.10103, Train Acc: 0.82759, Val Acc: 0.61017
# Epoch: 012, Loss: 1.09690, Train Acc: 0.80460, Val Acc: 0.59322
# Epoch: 013, Loss: 1.12151, Train Acc: 0.77011, Val Acc: 0.59322
# Epoch: 014, Loss: 1.09097, Train Acc: 0.82759, Val Acc: 0.57627
# Epoch: 015, Loss: 1.08737, Train Acc: 0.81609, Val Acc: 0.57627
# Epoch: 016, Loss: 1.10398, Train Acc: 0.81609, Val Acc: 0.57627
# Epoch: 017, Loss: 1.10416, Train Acc: 0.80460, Val Acc: 0.59322
# Epoch: 018, Loss: 1.09585, Train Acc: 0.81609, Val Acc: 0.57627
# Epoch: 019, Loss: 1.09484, Train Acc: 0.81609, Val Acc: 0.59322
# Epoch: 020, Loss: 1.07851, Train Acc: 0.83908, Val Acc: 0.59322
# Epoch: 021, Loss: 1.09259, Train Acc: 0.80460, Val Acc: 0.55932
# Epoch: 022, Loss: 1.09500, Train Acc: 0.82759, Val Acc: 0.55932
# Epoch: 023, Loss: 1.07646, Train Acc: 0.80460, Val Acc: 0.55932
# Epoch: 024, Loss: 1.07771, Train Acc: 0.83908, Val Acc: 0.52542
# Epoch: 025, Loss: 1.08355, Train Acc: 0.81609, Val Acc: 0.52542
# Epoch: 026, Loss: 1.10365, Train Acc: 0.81609, Val Acc: 0.55932
# Epoch: 027, Loss: 1.09472, Train Acc: 0.79310, Val Acc: 0.55932
# Epoch: 028, Loss: 1.06502, Train Acc: 0.86207, Val Acc: 0.52542
# Epoch: 029, Loss: 1.07392, Train Acc: 0.83908, Val Acc: 0.54237
# Epoch: 030, Loss: 1.06588, Train Acc: 0.85057, Val Acc: 0.54237
# Epoch: 031, Loss: 1.05468, Train Acc: 0.86207, Val Acc: 0.55932
# Epoch: 032, Loss: 1.03316, Train Acc: 0.89655, Val Acc: 0.54237
# Epoch: 033, Loss: 1.08484, Train Acc: 0.83908, Val Acc: 0.54237
# Epoch: 034, Loss: 1.07760, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 035, Loss: 1.05151, Train Acc: 0.85057, Val Acc: 0.54237
# Epoch: 036, Loss: 1.06489, Train Acc: 0.83908, Val Acc: 0.54237
# Epoch: 037, Loss: 1.07946, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 038, Loss: 1.04176, Train Acc: 0.85057, Val Acc: 0.54237
# Epoch: 039, Loss: 1.06702, Train Acc: 0.83908, Val Acc: 0.54237
# Epoch: 040, Loss: 1.02698, Train Acc: 0.88506, Val Acc: 0.54237
# Epoch: 041, Loss: 1.01299, Train Acc: 0.89655, Val Acc: 0.54237
# Epoch: 042, Loss: 1.03049, Train Acc: 0.89655, Val Acc: 0.54237
# Epoch: 043, Loss: 1.04901, Train Acc: 0.86207, Val Acc: 0.50847
# Epoch: 044, Loss: 1.03423, Train Acc: 0.88506, Val Acc: 0.50847
# Epoch: 045, Loss: 1.06088, Train Acc: 0.85057, Val Acc: 0.49153
# Epoch: 046, Loss: 1.06496, Train Acc: 0.85057, Val Acc: 0.49153
# Epoch: 047, Loss: 1.05028, Train Acc: 0.83908, Val Acc: 0.49153
# Epoch: 048, Loss: 1.05618, Train Acc: 0.86207, Val Acc: 0.49153
# Epoch: 049, Loss: 1.05171, Train Acc: 0.87356, Val Acc: 0.49153
# Epoch: 050, Loss: 1.04728, Train Acc: 0.85057, Val Acc: 0.49153
# Epoch: 051, Loss: 1.03119, Train Acc: 0.88506, Val Acc: 0.49153
# Epoch: 052, Loss: 1.06390, Train Acc: 0.85057, Val Acc: 0.49153
# Epoch: 053, Loss: 1.05546, Train Acc: 0.86207, Val Acc: 0.47458
# Epoch: 054, Loss: 1.05175, Train Acc: 0.88506, Val Acc: 0.49153
# Epoch: 055, Loss: 1.04080, Train Acc: 0.88506, Val Acc: 0.49153
# Epoch: 056, Loss: 1.04168, Train Acc: 0.87356, Val Acc: 0.49153
# Epoch: 057, Loss: 1.05012, Train Acc: 0.87356, Val Acc: 0.47458
# Epoch: 058, Loss: 1.06795, Train Acc: 0.83908, Val Acc: 0.47458
# Epoch: 059, Loss: 1.05176, Train Acc: 0.85057, Val Acc: 0.49153
# Epoch: 060, Loss: 1.03922, Train Acc: 0.87356, Val Acc: 0.49153
# Epoch: 061, Loss: 1.03447, Train Acc: 0.88506, Val Acc: 0.49153
# Epoch: 062, Loss: 1.06283, Train Acc: 0.83908, Val Acc: 0.49153
# Epoch: 063, Loss: 1.04952, Train Acc: 0.86207, Val Acc: 0.47458
# Epoch: 064, Loss: 1.05243, Train Acc: 0.86207, Val Acc: 0.47458
# Epoch: 065, Loss: 1.04360, Train Acc: 0.87356, Val Acc: 0.45763
# Epoch: 066, Loss: 1.03438, Train Acc: 0.87356, Val Acc: 0.47458
# Epoch: 067, Loss: 1.04321, Train Acc: 0.88506, Val Acc: 0.49153
# Epoch: 068, Loss: 1.04533, Train Acc: 0.86207, Val Acc: 0.49153
# Epoch: 069, Loss: 1.02874, Train Acc: 0.90805, Val Acc: 0.49153
# Epoch: 070, Loss: 1.02456, Train Acc: 0.90805, Val Acc: 0.47458
# Epoch: 071, Loss: 1.04295, Train Acc: 0.89655, Val Acc: 0.45763
# Epoch: 072, Loss: 1.02748, Train Acc: 0.87356, Val Acc: 0.49153
# Epoch: 073, Loss: 1.03137, Train Acc: 0.88506, Val Acc: 0.49153
# Epoch: 074, Loss: 1.05715, Train Acc: 0.86207, Val Acc: 0.49153
# Epoch: 075, Loss: 1.06844, Train Acc: 0.83908, Val Acc: 0.49153
# Epoch: 076, Loss: 1.04993, Train Acc: 0.85057, Val Acc: 0.47458
# Epoch: 077, Loss: 1.03430, Train Acc: 0.89655, Val Acc: 0.49153
# Epoch: 078, Loss: 1.03152, Train Acc: 0.88506, Val Acc: 0.49153
# Epoch: 079, Loss: 1.02040, Train Acc: 0.89655, Val Acc: 0.49153
# Epoch: 080, Loss: 1.05392, Train Acc: 0.87356, Val Acc: 0.50847
# Epoch: 081, Loss: 1.03583, Train Acc: 0.88506, Val Acc: 0.47458
# Epoch: 082, Loss: 1.02531, Train Acc: 0.88506, Val Acc: 0.47458
# Epoch: 083, Loss: 1.02449, Train Acc: 0.88506, Val Acc: 0.47458
# Epoch: 084, Loss: 1.02910, Train Acc: 0.88506, Val Acc: 0.47458
# Epoch: 085, Loss: 1.04427, Train Acc: 0.88506, Val Acc: 0.47458
# Epoch: 086, Loss: 1.03258, Train Acc: 0.90805, Val Acc: 0.47458
# Epoch: 087, Loss: 1.04007, Train Acc: 0.86207, Val Acc: 0.47458
# Epoch: 088, Loss: 1.05779, Train Acc: 0.86207, Val Acc: 0.47458
# Epoch: 089, Loss: 1.03321, Train Acc: 0.90805, Val Acc: 0.47458
# Epoch: 090, Loss: 1.02803, Train Acc: 0.88506, Val Acc: 0.47458
# Epoch: 091, Loss: 1.08376, Train Acc: 0.81609, Val Acc: 0.47458
# Epoch: 092, Loss: 1.01877, Train Acc: 0.88506, Val Acc: 0.47458
# Epoch: 093, Loss: 1.03165, Train Acc: 0.88506, Val Acc: 0.47458
# Epoch: 094, Loss: 1.01119, Train Acc: 0.90805, Val Acc: 0.47458
# Epoch: 095, Loss: 1.04069, Train Acc: 0.86207, Val Acc: 0.47458
# Epoch: 096, Loss: 1.03327, Train Acc: 0.89655, Val Acc: 0.44068
# Epoch: 097, Loss: 1.05373, Train Acc: 0.85057, Val Acc: 0.44068
# Epoch: 098, Loss: 1.03995, Train Acc: 0.87356, Val Acc: 0.47458
# Epoch: 099, Loss: 1.01964, Train Acc: 0.89655, Val Acc: 0.47458
# Epoch: 100, Loss: 1.02038, Train Acc: 0.88506, Val Acc: 0.47458
# Test Accuracy: 0.43243
# Random State 4734510  in the iteration 5
# Epoch: 001, Loss: 1.26174, Train Acc: 0.64368, Val Acc: 0.66102
# Epoch: 002, Loss: 1.23392, Train Acc: 0.68966, Val Acc: 0.66102
# Epoch: 003, Loss: 1.26601, Train Acc: 0.63218, Val Acc: 0.66102
# Epoch: 004, Loss: 1.22594, Train Acc: 0.68966, Val Acc: 0.66102
# Epoch: 005, Loss: 1.21396, Train Acc: 0.71264, Val Acc: 0.64407
# Epoch: 006, Loss: 1.19397, Train Acc: 0.72414, Val Acc: 0.62712
# Epoch: 007, Loss: 1.18694, Train Acc: 0.71264, Val Acc: 0.62712
# Epoch: 008, Loss: 1.16419, Train Acc: 0.77011, Val Acc: 0.64407
# Epoch: 009, Loss: 1.16387, Train Acc: 0.75862, Val Acc: 0.66102
# Epoch: 010, Loss: 1.16678, Train Acc: 0.74713, Val Acc: 0.66102
# Epoch: 011, Loss: 1.16943, Train Acc: 0.72414, Val Acc: 0.66102
# Epoch: 012, Loss: 1.16578, Train Acc: 0.74713, Val Acc: 0.61017
# Epoch: 013, Loss: 1.15796, Train Acc: 0.78161, Val Acc: 0.67797
# Epoch: 014, Loss: 1.14293, Train Acc: 0.78161, Val Acc: 0.64407
# Epoch: 015, Loss: 1.14925, Train Acc: 0.74713, Val Acc: 0.61017
# Epoch: 016, Loss: 1.18144, Train Acc: 0.72414, Val Acc: 0.61017
# Epoch: 017, Loss: 1.16630, Train Acc: 0.73563, Val Acc: 0.61017
# Epoch: 018, Loss: 1.12542, Train Acc: 0.78161, Val Acc: 0.61017
# Epoch: 019, Loss: 1.13168, Train Acc: 0.79310, Val Acc: 0.59322
# Epoch: 020, Loss: 1.12299, Train Acc: 0.77011, Val Acc: 0.59322
# Epoch: 021, Loss: 1.11902, Train Acc: 0.80460, Val Acc: 0.57627
# Epoch: 022, Loss: 1.14836, Train Acc: 0.78161, Val Acc: 0.57627
# Epoch: 023, Loss: 1.10748, Train Acc: 0.79310, Val Acc: 0.57627
# Epoch: 024, Loss: 1.10672, Train Acc: 0.79310, Val Acc: 0.57627
# Epoch: 025, Loss: 1.12112, Train Acc: 0.78161, Val Acc: 0.57627
# Epoch: 026, Loss: 1.09727, Train Acc: 0.82759, Val Acc: 0.55932
# Epoch: 027, Loss: 1.13484, Train Acc: 0.78161, Val Acc: 0.57627
# Epoch: 028, Loss: 1.08178, Train Acc: 0.85057, Val Acc: 0.59322
# Epoch: 029, Loss: 1.06601, Train Acc: 0.85057, Val Acc: 0.59322
# Epoch: 030, Loss: 1.09965, Train Acc: 0.81609, Val Acc: 0.59322
# Epoch: 031, Loss: 1.10757, Train Acc: 0.80460, Val Acc: 0.57627
# Epoch: 032, Loss: 1.10800, Train Acc: 0.81609, Val Acc: 0.57627
# Epoch: 033, Loss: 1.06879, Train Acc: 0.83908, Val Acc: 0.57627
# Epoch: 034, Loss: 1.11072, Train Acc: 0.79310, Val Acc: 0.57627
# Epoch: 035, Loss: 1.08847, Train Acc: 0.82759, Val Acc: 0.55932
# Epoch: 036, Loss: 1.11557, Train Acc: 0.80460, Val Acc: 0.55932
# Epoch: 037, Loss: 1.08176, Train Acc: 0.83908, Val Acc: 0.55932
# Epoch: 038, Loss: 1.06022, Train Acc: 0.86207, Val Acc: 0.55932
# Epoch: 039, Loss: 1.10011, Train Acc: 0.81609, Val Acc: 0.57627
# Epoch: 040, Loss: 1.08514, Train Acc: 0.83908, Val Acc: 0.57627
# Epoch: 041, Loss: 1.09528, Train Acc: 0.80460, Val Acc: 0.59322
# Epoch: 042, Loss: 1.08681, Train Acc: 0.81609, Val Acc: 0.57627
# Epoch: 043, Loss: 1.11972, Train Acc: 0.78161, Val Acc: 0.57627
# Epoch: 044, Loss: 1.04414, Train Acc: 0.87356, Val Acc: 0.57627
# Epoch: 045, Loss: 1.10485, Train Acc: 0.80460, Val Acc: 0.57627
# Epoch: 046, Loss: 1.06227, Train Acc: 0.85057, Val Acc: 0.57627
# Epoch: 047, Loss: 1.07544, Train Acc: 0.82759, Val Acc: 0.57627
# Epoch: 048, Loss: 1.06349, Train Acc: 0.85057, Val Acc: 0.57627
# Epoch: 049, Loss: 1.07180, Train Acc: 0.85057, Val Acc: 0.55932
# Epoch: 050, Loss: 1.04076, Train Acc: 0.87356, Val Acc: 0.55932
# Epoch: 051, Loss: 1.08321, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 052, Loss: 1.06849, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 053, Loss: 1.05907, Train Acc: 0.85057, Val Acc: 0.54237
# Epoch: 054, Loss: 1.10144, Train Acc: 0.81609, Val Acc: 0.54237
# Epoch: 055, Loss: 1.06024, Train Acc: 0.86207, Val Acc: 0.55932
# Epoch: 056, Loss: 1.06531, Train Acc: 0.85057, Val Acc: 0.55932
# Epoch: 057, Loss: 1.08044, Train Acc: 0.83908, Val Acc: 0.55932
# Epoch: 058, Loss: 1.03201, Train Acc: 0.89655, Val Acc: 0.55932
# Epoch: 059, Loss: 1.06215, Train Acc: 0.85057, Val Acc: 0.57627
# Epoch: 060, Loss: 1.06455, Train Acc: 0.85057, Val Acc: 0.55932
# Epoch: 061, Loss: 1.05509, Train Acc: 0.86207, Val Acc: 0.55932
# Epoch: 062, Loss: 1.06591, Train Acc: 0.85057, Val Acc: 0.59322
# Epoch: 063, Loss: 1.05450, Train Acc: 0.85057, Val Acc: 0.57627
# Epoch: 064, Loss: 1.08552, Train Acc: 0.81609, Val Acc: 0.55932
# Epoch: 065, Loss: 1.03605, Train Acc: 0.89655, Val Acc: 0.52542
# Epoch: 066, Loss: 1.06304, Train Acc: 0.86207, Val Acc: 0.52542
# Epoch: 067, Loss: 1.07311, Train Acc: 0.82759, Val Acc: 0.52542
# Epoch: 068, Loss: 1.07159, Train Acc: 0.83908, Val Acc: 0.55932
# Epoch: 069, Loss: 1.05770, Train Acc: 0.85057, Val Acc: 0.59322
# Epoch: 070, Loss: 1.06942, Train Acc: 0.83908, Val Acc: 0.57627
# Epoch: 071, Loss: 1.05579, Train Acc: 0.86207, Val Acc: 0.57627
# Epoch: 072, Loss: 1.04858, Train Acc: 0.85057, Val Acc: 0.57627
# Epoch: 073, Loss: 1.07986, Train Acc: 0.82759, Val Acc: 0.55932
# Epoch: 074, Loss: 1.07036, Train Acc: 0.85057, Val Acc: 0.54237
# Epoch: 075, Loss: 1.06001, Train Acc: 0.86207, Val Acc: 0.54237
# Epoch: 076, Loss: 1.05964, Train Acc: 0.85057, Val Acc: 0.52542
# Epoch: 077, Loss: 1.03936, Train Acc: 0.89655, Val Acc: 0.52542
# Epoch: 078, Loss: 1.07133, Train Acc: 0.86207, Val Acc: 0.52542
# Epoch: 079, Loss: 1.07996, Train Acc: 0.83908, Val Acc: 0.50847
# Epoch: 080, Loss: 1.06759, Train Acc: 0.85057, Val Acc: 0.52542
# Epoch: 081, Loss: 1.04883, Train Acc: 0.86207, Val Acc: 0.52542
# Epoch: 082, Loss: 1.08151, Train Acc: 0.83908, Val Acc: 0.54237
# Epoch: 083, Loss: 1.03748, Train Acc: 0.87356, Val Acc: 0.54237
# Epoch: 084, Loss: 1.07199, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 085, Loss: 1.06531, Train Acc: 0.86207, Val Acc: 0.54237
# Epoch: 086, Loss: 1.04779, Train Acc: 0.86207, Val Acc: 0.52542
# Epoch: 087, Loss: 1.06236, Train Acc: 0.87356, Val Acc: 0.52542
# Epoch: 088, Loss: 1.07405, Train Acc: 0.82759, Val Acc: 0.54237
# Epoch: 089, Loss: 1.04412, Train Acc: 0.86207, Val Acc: 0.55932
# Epoch: 090, Loss: 0.99900, Train Acc: 0.93103, Val Acc: 0.55932
# Epoch: 091, Loss: 1.06177, Train Acc: 0.85057, Val Acc: 0.54237
# Epoch: 092, Loss: 1.03572, Train Acc: 0.87356, Val Acc: 0.54237
# Epoch: 093, Loss: 1.05778, Train Acc: 0.86207, Val Acc: 0.52542
# Epoch: 094, Loss: 1.06337, Train Acc: 0.83908, Val Acc: 0.52542
# Epoch: 095, Loss: 1.02895, Train Acc: 0.89655, Val Acc: 0.52542
# Epoch: 096, Loss: 1.05609, Train Acc: 0.86207, Val Acc: 0.52542
# Epoch: 097, Loss: 1.04554, Train Acc: 0.87356, Val Acc: 0.52542
# Epoch: 098, Loss: 1.09663, Train Acc: 0.80460, Val Acc: 0.52542
# Epoch: 099, Loss: 1.05325, Train Acc: 0.87356, Val Acc: 0.49153
# Epoch: 100, Loss: 1.03813, Train Acc: 0.86207, Val Acc: 0.50847
# Test Accuracy: 0.56757
# Random State 654321  in the iteration 6
# Epoch: 001, Loss: 1.28029, Train Acc: 0.65517, Val Acc: 0.76271
# Epoch: 002, Loss: 1.28593, Train Acc: 0.63218, Val Acc: 0.76271
# Epoch: 003, Loss: 1.28042, Train Acc: 0.63218, Val Acc: 0.79661
# Epoch: 004, Loss: 1.29478, Train Acc: 0.59770, Val Acc: 0.81356
# Epoch: 005, Loss: 1.25817, Train Acc: 0.62069, Val Acc: 0.77966
# Epoch: 006, Loss: 1.31042, Train Acc: 0.55172, Val Acc: 0.76271
# Epoch: 007, Loss: 1.28338, Train Acc: 0.60920, Val Acc: 0.76271
# Epoch: 008, Loss: 1.19178, Train Acc: 0.71264, Val Acc: 0.76271
# Epoch: 009, Loss: 1.23436, Train Acc: 0.67816, Val Acc: 0.76271
# Epoch: 010, Loss: 1.21833, Train Acc: 0.67816, Val Acc: 0.69492
# Epoch: 011, Loss: 1.19912, Train Acc: 0.72414, Val Acc: 0.66102
# Epoch: 012, Loss: 1.20854, Train Acc: 0.72414, Val Acc: 0.67797
# Epoch: 013, Loss: 1.16038, Train Acc: 0.74713, Val Acc: 0.67797
# Epoch: 014, Loss: 1.26110, Train Acc: 0.59770, Val Acc: 0.69492
# Epoch: 015, Loss: 1.12484, Train Acc: 0.79310, Val Acc: 0.69492
# Epoch: 016, Loss: 1.15051, Train Acc: 0.78161, Val Acc: 0.69492
# Epoch: 017, Loss: 1.16160, Train Acc: 0.77011, Val Acc: 0.69492
# Epoch: 018, Loss: 1.16732, Train Acc: 0.73563, Val Acc: 0.69492
# Epoch: 019, Loss: 1.16733, Train Acc: 0.74713, Val Acc: 0.69492
# Epoch: 020, Loss: 1.13971, Train Acc: 0.80460, Val Acc: 0.71186
# Epoch: 021, Loss: 1.13994, Train Acc: 0.78161, Val Acc: 0.69492
# Epoch: 022, Loss: 1.14325, Train Acc: 0.78161, Val Acc: 0.69492
# Epoch: 023, Loss: 1.14502, Train Acc: 0.75862, Val Acc: 0.69492
# Epoch: 024, Loss: 1.12099, Train Acc: 0.79310, Val Acc: 0.69492
# Epoch: 025, Loss: 1.15278, Train Acc: 0.78161, Val Acc: 0.71186
# Epoch: 026, Loss: 1.14223, Train Acc: 0.77011, Val Acc: 0.66102
# Epoch: 027, Loss: 1.10291, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 028, Loss: 1.12161, Train Acc: 0.77011, Val Acc: 0.64407
# Epoch: 029, Loss: 1.11442, Train Acc: 0.80460, Val Acc: 0.66102
# Epoch: 030, Loss: 1.12934, Train Acc: 0.77011, Val Acc: 0.66102
# Epoch: 031, Loss: 1.10005, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 032, Loss: 1.09428, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 033, Loss: 1.10534, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 034, Loss: 1.09181, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 035, Loss: 1.11869, Train Acc: 0.79310, Val Acc: 0.64407
# Epoch: 036, Loss: 1.12010, Train Acc: 0.77011, Val Acc: 0.66102
# Epoch: 037, Loss: 1.11774, Train Acc: 0.78161, Val Acc: 0.69492
# Epoch: 038, Loss: 1.06548, Train Acc: 0.86207, Val Acc: 0.69492
# Epoch: 039, Loss: 1.10059, Train Acc: 0.80460, Val Acc: 0.69492
# Epoch: 040, Loss: 1.11744, Train Acc: 0.79310, Val Acc: 0.69492
# Epoch: 041, Loss: 1.10204, Train Acc: 0.80460, Val Acc: 0.69492
# Epoch: 042, Loss: 1.13781, Train Acc: 0.79310, Val Acc: 0.69492
# Epoch: 043, Loss: 1.08646, Train Acc: 0.82759, Val Acc: 0.69492
# Epoch: 044, Loss: 1.13982, Train Acc: 0.79310, Val Acc: 0.67797
# Epoch: 045, Loss: 1.07803, Train Acc: 0.85057, Val Acc: 0.67797
# Epoch: 046, Loss: 1.07577, Train Acc: 0.83908, Val Acc: 0.67797
# Epoch: 047, Loss: 1.10324, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 048, Loss: 1.09096, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 049, Loss: 1.11833, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 050, Loss: 1.05816, Train Acc: 0.86207, Val Acc: 0.66102
# Epoch: 051, Loss: 1.07515, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 052, Loss: 1.09433, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 053, Loss: 1.11455, Train Acc: 0.79310, Val Acc: 0.66102
# Epoch: 054, Loss: 1.04008, Train Acc: 0.88506, Val Acc: 0.66102
# Epoch: 055, Loss: 1.08806, Train Acc: 0.85057, Val Acc: 0.66102
# Epoch: 056, Loss: 1.05406, Train Acc: 0.86207, Val Acc: 0.66102
# Epoch: 057, Loss: 1.10071, Train Acc: 0.79310, Val Acc: 0.66102
# Epoch: 058, Loss: 1.09847, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 059, Loss: 1.07049, Train Acc: 0.85057, Val Acc: 0.66102
# Epoch: 060, Loss: 1.05967, Train Acc: 0.86207, Val Acc: 0.66102
# Epoch: 061, Loss: 1.07655, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 062, Loss: 1.05862, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 063, Loss: 1.09419, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 064, Loss: 1.04933, Train Acc: 0.88506, Val Acc: 0.64407
# Epoch: 065, Loss: 1.07625, Train Acc: 0.85057, Val Acc: 0.62712
# Epoch: 066, Loss: 1.05922, Train Acc: 0.86207, Val Acc: 0.62712
# Epoch: 067, Loss: 1.06886, Train Acc: 0.85057, Val Acc: 0.64407
# Epoch: 068, Loss: 1.03377, Train Acc: 0.88506, Val Acc: 0.64407
# Epoch: 069, Loss: 1.06185, Train Acc: 0.87356, Val Acc: 0.66102
# Epoch: 070, Loss: 1.09133, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 071, Loss: 1.08525, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 072, Loss: 1.08303, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 073, Loss: 1.03463, Train Acc: 0.88506, Val Acc: 0.64407
# Epoch: 074, Loss: 1.06840, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 075, Loss: 1.06431, Train Acc: 0.86207, Val Acc: 0.62712
# Epoch: 076, Loss: 1.04640, Train Acc: 0.87356, Val Acc: 0.62712
# Epoch: 077, Loss: 1.08624, Train Acc: 0.85057, Val Acc: 0.61017
# Epoch: 078, Loss: 1.07942, Train Acc: 0.83908, Val Acc: 0.61017
# Epoch: 079, Loss: 1.03834, Train Acc: 0.88506, Val Acc: 0.61017
# Epoch: 080, Loss: 1.07311, Train Acc: 0.85057, Val Acc: 0.61017
# Epoch: 081, Loss: 1.04730, Train Acc: 0.86207, Val Acc: 0.59322
# Epoch: 082, Loss: 1.07659, Train Acc: 0.83908, Val Acc: 0.62712
# Epoch: 083, Loss: 1.04095, Train Acc: 0.88506, Val Acc: 0.62712
# Epoch: 084, Loss: 1.04394, Train Acc: 0.87356, Val Acc: 0.64407
# Epoch: 085, Loss: 1.03880, Train Acc: 0.89655, Val Acc: 0.64407
# Epoch: 086, Loss: 1.09237, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 087, Loss: 1.05762, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 088, Loss: 1.05447, Train Acc: 0.85057, Val Acc: 0.59322
# Epoch: 089, Loss: 1.05422, Train Acc: 0.87356, Val Acc: 0.59322
# Epoch: 090, Loss: 1.07282, Train Acc: 0.81609, Val Acc: 0.59322
# Epoch: 091, Loss: 1.03416, Train Acc: 0.88506, Val Acc: 0.59322
# Epoch: 092, Loss: 1.07128, Train Acc: 0.86207, Val Acc: 0.59322
# Epoch: 093, Loss: 1.06970, Train Acc: 0.85057, Val Acc: 0.59322
# Epoch: 094, Loss: 1.03646, Train Acc: 0.88506, Val Acc: 0.64407
# Epoch: 095, Loss: 1.05198, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 096, Loss: 1.05563, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 097, Loss: 1.04971, Train Acc: 0.88506, Val Acc: 0.64407
# Epoch: 098, Loss: 1.05658, Train Acc: 0.86207, Val Acc: 0.64407
# Epoch: 099, Loss: 1.04239, Train Acc: 0.88506, Val Acc: 0.64407
# Epoch: 100, Loss: 1.05193, Train Acc: 0.86207, Val Acc: 0.66102
# Test Accuracy: 0.51351
# Random State 124321  in the iteration 7
# Epoch: 001, Loss: 1.16788, Train Acc: 0.73563, Val Acc: 0.71186
# Epoch: 002, Loss: 1.15944, Train Acc: 0.77011, Val Acc: 0.67797
# Epoch: 003, Loss: 1.14054, Train Acc: 0.75862, Val Acc: 0.66102
# Epoch: 004, Loss: 1.12417, Train Acc: 0.79310, Val Acc: 0.67797
# Epoch: 005, Loss: 1.16299, Train Acc: 0.75862, Val Acc: 0.67797
# Epoch: 006, Loss: 1.14942, Train Acc: 0.75862, Val Acc: 0.66102
# Epoch: 007, Loss: 1.14298, Train Acc: 0.78161, Val Acc: 0.67797
# Epoch: 008, Loss: 1.15936, Train Acc: 0.75862, Val Acc: 0.64407
# Epoch: 009, Loss: 1.15030, Train Acc: 0.77011, Val Acc: 0.64407
# Epoch: 010, Loss: 1.12414, Train Acc: 0.80460, Val Acc: 0.64407
# Epoch: 011, Loss: 1.10911, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 012, Loss: 1.12008, Train Acc: 0.79310, Val Acc: 0.67797
# Epoch: 013, Loss: 1.08058, Train Acc: 0.82759, Val Acc: 0.67797
# Epoch: 014, Loss: 1.12711, Train Acc: 0.77011, Val Acc: 0.67797
# Epoch: 015, Loss: 1.10879, Train Acc: 0.80460, Val Acc: 0.67797
# Epoch: 016, Loss: 1.13057, Train Acc: 0.79310, Val Acc: 0.67797
# Epoch: 017, Loss: 1.10356, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 018, Loss: 1.14150, Train Acc: 0.77011, Val Acc: 0.67797
# Epoch: 019, Loss: 1.10563, Train Acc: 0.81609, Val Acc: 0.66102
# Epoch: 020, Loss: 1.09974, Train Acc: 0.81609, Val Acc: 0.67797
# Epoch: 021, Loss: 1.10270, Train Acc: 0.80460, Val Acc: 0.67797
# Epoch: 022, Loss: 1.11159, Train Acc: 0.79310, Val Acc: 0.71186
# Epoch: 023, Loss: 1.11024, Train Acc: 0.81609, Val Acc: 0.67797
# Epoch: 024, Loss: 1.07989, Train Acc: 0.82759, Val Acc: 0.67797
# Epoch: 025, Loss: 1.10135, Train Acc: 0.81609, Val Acc: 0.67797
# Epoch: 026, Loss: 1.07496, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 027, Loss: 1.09955, Train Acc: 0.81609, Val Acc: 0.64407
# Epoch: 028, Loss: 1.09267, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 029, Loss: 1.07999, Train Acc: 0.83908, Val Acc: 0.66102
# Epoch: 030, Loss: 1.08392, Train Acc: 0.85057, Val Acc: 0.64407
# Epoch: 031, Loss: 1.08774, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 032, Loss: 1.09229, Train Acc: 0.82759, Val Acc: 0.64407
# Epoch: 033, Loss: 1.08640, Train Acc: 0.82759, Val Acc: 0.66102
# Epoch: 034, Loss: 1.07070, Train Acc: 0.83908, Val Acc: 0.62712
# Epoch: 035, Loss: 1.08516, Train Acc: 0.81609, Val Acc: 0.62712
# Epoch: 036, Loss: 1.08230, Train Acc: 0.85057, Val Acc: 0.62712
# Epoch: 037, Loss: 1.07174, Train Acc: 0.83908, Val Acc: 0.64407
# Epoch: 038, Loss: 1.05190, Train Acc: 0.85057, Val Acc: 0.64407
# Epoch: 039, Loss: 1.13669, Train Acc: 0.75862, Val Acc: 0.62712
# Epoch: 040, Loss: 1.08485, Train Acc: 0.82759, Val Acc: 0.64407
# ...
# Epoch: 055, Loss: 0.95003, Train Acc: 0.95402, Val Acc: 0.89831
# Epoch: 056, Loss: 0.97074, Train Acc: 0.94253, Val Acc: 0.89831
# Epoch: 057, Loss: 0.97679, Train Acc: 0.93103, Val Acc: 0.89831
# Epoch: 058, Loss: 0.95655, Train Acc: 0.95402, Val Acc: 0.89831
# Epoch: 059, Loss: 0.91648, Train Acc: 1.00000, Val Acc: 0.91525
# Epoch: 060, Loss: 0.94758, Train Acc: 0.96552, Val Acc: 0.91525
# Epoch: 061, Loss: 0.92339, Train Acc: 0.98851, Val Acc: 0.91525
# Epoch: 062, Loss: 0.92144, Train Acc: 0.98851, Val Acc: 0.91525
# Epoch: 063, Loss: 0.95797, Train Acc: 0.95402, Val Acc: 0.91525
# Epoch: 064, Loss: 0.94539, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 065, Loss: 0.92243, Train Acc: 1.00000, Val Acc: 0.91525
# Epoch: 066, Loss: 0.96207, Train Acc: 0.95402, Val Acc: 0.91525
# Epoch: 067, Loss: 0.95857, Train Acc: 0.95402, Val Acc: 0.91525
# Epoch: 068, Loss: 0.95060, Train Acc: 0.96552, Val Acc: 0.91525
# Epoch: 069, Loss: 0.93908, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 070, Loss: 0.93848, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 071, Loss: 0.94081, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 072, Loss: 0.94278, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 073, Loss: 0.97350, Train Acc: 0.93103, Val Acc: 0.91525
# Epoch: 074, Loss: 0.95085, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 075, Loss: 0.93048, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 076, Loss: 0.94349, Train Acc: 0.96552, Val Acc: 0.91525
# Epoch: 077, Loss: 0.92184, Train Acc: 1.00000, Val Acc: 0.89831
# Epoch: 078, Loss: 0.95744, Train Acc: 0.95402, Val Acc: 0.89831
# Epoch: 079, Loss: 0.96894, Train Acc: 0.94253, Val Acc: 0.89831
# Epoch: 080, Loss: 0.95385, Train Acc: 0.95402, Val Acc: 0.89831
# Epoch: 081, Loss: 0.93637, Train Acc: 0.97701, Val Acc: 0.89831
# Epoch: 082, Loss: 0.91076, Train Acc: 1.00000, Val Acc: 0.89831
# Epoch: 083, Loss: 0.95617, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 084, Loss: 0.92493, Train Acc: 0.98851, Val Acc: 0.91525
# Epoch: 085, Loss: 0.92529, Train Acc: 0.98851, Val Acc: 0.91525
# Epoch: 086, Loss: 0.93953, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 087, Loss: 0.91873, Train Acc: 0.98851, Val Acc: 0.91525
# Epoch: 088, Loss: 0.95434, Train Acc: 0.95402, Val Acc: 0.91525
# Epoch: 089, Loss: 0.94555, Train Acc: 0.96552, Val Acc: 0.91525
# Epoch: 090, Loss: 0.94541, Train Acc: 0.96552, Val Acc: 0.91525
# Epoch: 091, Loss: 0.92656, Train Acc: 0.98851, Val Acc: 0.91525
# Epoch: 092, Loss: 0.92816, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 093, Loss: 0.94028, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 094, Loss: 0.92796, Train Acc: 0.98851, Val Acc: 0.91525
# Epoch: 095, Loss: 0.94518, Train Acc: 0.96552, Val Acc: 0.91525
# Epoch: 096, Loss: 0.93269, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 097, Loss: 0.95917, Train Acc: 0.95402, Val Acc: 0.91525
# Epoch: 098, Loss: 1.01607, Train Acc: 0.88506, Val Acc: 0.91525
# Epoch: 099, Loss: 0.95339, Train Acc: 0.94253, Val Acc: 0.91525
# Epoch: 100, Loss: 0.95184, Train Acc: 0.96552, Val Acc: 0.89831
# Test Accuracy: 0.83784
# Random State 945321  in the iteration 8
# Epoch: 001, Loss: 1.03091, Train Acc: 0.88506, Val Acc: 0.93220
# Epoch: 002, Loss: 1.01601, Train Acc: 0.87356, Val Acc: 0.91525
# Epoch: 003, Loss: 0.98382, Train Acc: 0.91954, Val Acc: 0.91525
# Epoch: 004, Loss: 0.94600, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 005, Loss: 0.98115, Train Acc: 0.94253, Val Acc: 0.89831
# Epoch: 006, Loss: 0.99028, Train Acc: 0.93103, Val Acc: 0.89831
# Epoch: 007, Loss: 0.98338, Train Acc: 0.94253, Val Acc: 0.89831
# Epoch: 008, Loss: 0.95175, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 009, Loss: 0.94003, Train Acc: 0.98851, Val Acc: 0.89831
# Epoch: 010, Loss: 0.94963, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 011, Loss: 0.98163, Train Acc: 0.94253, Val Acc: 0.89831
# Epoch: 012, Loss: 0.95689, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 013, Loss: 0.94101, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 014, Loss: 0.95859, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 015, Loss: 0.94417, Train Acc: 0.98851, Val Acc: 0.89831
# Epoch: 016, Loss: 0.98368, Train Acc: 0.94253, Val Acc: 0.91525
# Epoch: 017, Loss: 0.94158, Train Acc: 0.98851, Val Acc: 0.91525
# Epoch: 018, Loss: 0.98010, Train Acc: 0.93103, Val Acc: 0.91525
# Epoch: 019, Loss: 0.94632, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 020, Loss: 0.94700, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 021, Loss: 0.92775, Train Acc: 0.97701, Val Acc: 0.89831
# Epoch: 022, Loss: 0.94902, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 023, Loss: 0.95155, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 024, Loss: 0.96547, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 025, Loss: 0.94600, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 026, Loss: 0.97177, Train Acc: 0.95402, Val Acc: 0.89831
# Epoch: 027, Loss: 0.96653, Train Acc: 0.94253, Val Acc: 0.89831
# Epoch: 028, Loss: 0.93639, Train Acc: 0.97701, Val Acc: 0.89831
# Epoch: 029, Loss: 0.96587, Train Acc: 0.95402, Val Acc: 0.89831
# Epoch: 030, Loss: 0.96900, Train Acc: 0.95402, Val Acc: 0.88136
# Epoch: 031, Loss: 0.94117, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 032, Loss: 0.93843, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 033, Loss: 0.94303, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 034, Loss: 0.95426, Train Acc: 0.96552, Val Acc: 0.88136
# Epoch: 035, Loss: 0.96395, Train Acc: 0.95402, Val Acc: 0.88136
# Epoch: 036, Loss: 0.97180, Train Acc: 0.94253, Val Acc: 0.88136
# Epoch: 037, Loss: 0.94045, Train Acc: 0.97701, Val Acc: 0.86441
# Epoch: 038, Loss: 0.94720, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 039, Loss: 0.93113, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 040, Loss: 0.93172, Train Acc: 0.97701, Val Acc: 0.86441
# Epoch: 041, Loss: 0.93809, Train Acc: 0.97701, Val Acc: 0.86441
# Epoch: 042, Loss: 0.95131, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 043, Loss: 0.93147, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 044, Loss: 0.95261, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 045, Loss: 0.94882, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 046, Loss: 0.94637, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 047, Loss: 0.95095, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 048, Loss: 0.95813, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 049, Loss: 0.95007, Train Acc: 0.95402, Val Acc: 0.86441
# Epoch: 050, Loss: 0.95543, Train Acc: 0.95402, Val Acc: 0.86441
# Epoch: 051, Loss: 0.92313, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 052, Loss: 0.97294, Train Acc: 0.94253, Val Acc: 0.86441
# Epoch: 053, Loss: 0.95333, Train Acc: 0.95402, Val Acc: 0.86441
# Epoch: 054, Loss: 0.94811, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 055, Loss: 0.98058, Train Acc: 0.93103, Val Acc: 0.86441
# Epoch: 056, Loss: 0.93237, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 057, Loss: 0.94295, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 058, Loss: 0.94026, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 059, Loss: 0.92108, Train Acc: 1.00000, Val Acc: 0.86441
# Epoch: 060, Loss: 0.93169, Train Acc: 0.97701, Val Acc: 0.86441
# Epoch: 061, Loss: 0.94797, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 062, Loss: 0.91304, Train Acc: 1.00000, Val Acc: 0.86441
# Epoch: 063, Loss: 0.94006, Train Acc: 0.97701, Val Acc: 0.86441
# Epoch: 064, Loss: 0.95832, Train Acc: 0.95402, Val Acc: 0.86441
# Epoch: 065, Loss: 0.96287, Train Acc: 0.95402, Val Acc: 0.86441
# Epoch: 066, Loss: 0.92194, Train Acc: 1.00000, Val Acc: 0.86441
# Epoch: 067, Loss: 0.92871, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 068, Loss: 0.94861, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 069, Loss: 0.93589, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 070, Loss: 0.95332, Train Acc: 0.95402, Val Acc: 0.86441
# Epoch: 071, Loss: 0.94849, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 072, Loss: 0.96362, Train Acc: 0.95402, Val Acc: 0.86441
# Epoch: 073, Loss: 0.94241, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 074, Loss: 0.95516, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 075, Loss: 0.95259, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 076, Loss: 0.95923, Train Acc: 0.94253, Val Acc: 0.86441
# Epoch: 077, Loss: 0.97143, Train Acc: 0.94253, Val Acc: 0.86441
# Epoch: 078, Loss: 0.92309, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 079, Loss: 0.93396, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 080, Loss: 0.93787, Train Acc: 0.97701, Val Acc: 0.86441
# Epoch: 081, Loss: 0.94437, Train Acc: 0.97701, Val Acc: 0.86441
# Epoch: 082, Loss: 0.96507, Train Acc: 0.95402, Val Acc: 0.86441
# Epoch: 083, Loss: 0.95276, Train Acc: 0.95402, Val Acc: 0.86441
# Epoch: 084, Loss: 0.95599, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 085, Loss: 0.95065, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 086, Loss: 0.91294, Train Acc: 1.00000, Val Acc: 0.86441
# Epoch: 087, Loss: 0.92951, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 088, Loss: 0.94687, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 089, Loss: 0.94774, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 090, Loss: 0.94705, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 091, Loss: 0.97126, Train Acc: 0.94253, Val Acc: 0.86441
# Epoch: 092, Loss: 0.93883, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 093, Loss: 0.92688, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 094, Loss: 0.92086, Train Acc: 1.00000, Val Acc: 0.86441
# Epoch: 095, Loss: 0.95354, Train Acc: 0.95402, Val Acc: 0.84746
# Epoch: 096, Loss: 0.96020, Train Acc: 0.94253, Val Acc: 0.84746
# Epoch: 097, Loss: 0.94465, Train Acc: 0.95402, Val Acc: 0.84746
# Epoch: 098, Loss: 0.92399, Train Acc: 0.98851, Val Acc: 0.84746
# Epoch: 099, Loss: 0.91996, Train Acc: 1.00000, Val Acc: 0.84746
# Epoch: 100, Loss: 0.96153, Train Acc: 0.95402, Val Acc: 0.84746
# Test Accuracy: 0.91892
# Random State 784328  in the iteration 9
# Epoch: 001, Loss: 1.03895, Train Acc: 0.87356, Val Acc: 0.93220
# Epoch: 002, Loss: 0.98344, Train Acc: 0.91954, Val Acc: 0.93220
# Epoch: 003, Loss: 0.97539, Train Acc: 0.94253, Val Acc: 0.94915
# Epoch: 004, Loss: 1.02449, Train Acc: 0.90805, Val Acc: 0.93220
# Epoch: 005, Loss: 1.01979, Train Acc: 0.88506, Val Acc: 0.93220
# Epoch: 006, Loss: 0.95528, Train Acc: 0.96552, Val Acc: 0.94915
# Epoch: 007, Loss: 0.97270, Train Acc: 0.95402, Val Acc: 0.94915
# Epoch: 008, Loss: 0.99192, Train Acc: 0.91954, Val Acc: 0.96610
# Epoch: 009, Loss: 0.96092, Train Acc: 0.94253, Val Acc: 0.96610
# Epoch: 010, Loss: 0.95481, Train Acc: 0.95402, Val Acc: 0.96610
# Epoch: 011, Loss: 0.95360, Train Acc: 0.97701, Val Acc: 0.96610
# Epoch: 012, Loss: 0.94510, Train Acc: 0.97701, Val Acc: 0.96610
# Epoch: 013, Loss: 0.98770, Train Acc: 0.93103, Val Acc: 0.94915
# Epoch: 014, Loss: 0.95417, Train Acc: 0.95402, Val Acc: 0.94915
# Epoch: 015, Loss: 0.95420, Train Acc: 0.96552, Val Acc: 0.94915
# Epoch: 016, Loss: 0.94697, Train Acc: 0.97701, Val Acc: 0.96610
# Epoch: 017, Loss: 0.98077, Train Acc: 0.93103, Val Acc: 0.96610
# Epoch: 018, Loss: 0.93155, Train Acc: 0.98851, Val Acc: 0.94915
# Epoch: 019, Loss: 0.97146, Train Acc: 0.96552, Val Acc: 0.94915
# Epoch: 020, Loss: 0.94587, Train Acc: 0.97701, Val Acc: 0.94915
# Epoch: 021, Loss: 0.94302, Train Acc: 0.97701, Val Acc: 0.96610
# Epoch: 022, Loss: 0.95990, Train Acc: 0.95402, Val Acc: 0.96610
# Epoch: 023, Loss: 0.92846, Train Acc: 0.98851, Val Acc: 0.96610
# Epoch: 024, Loss: 0.94004, Train Acc: 0.97701, Val Acc: 0.94915
# Epoch: 025, Loss: 0.94371, Train Acc: 0.96552, Val Acc: 0.96610
# Epoch: 026, Loss: 0.94707, Train Acc: 0.96552, Val Acc: 0.96610
# Epoch: 027, Loss: 0.93069, Train Acc: 0.98851, Val Acc: 0.96610
# Epoch: 028, Loss: 0.93592, Train Acc: 0.97701, Val Acc: 0.96610
# Epoch: 029, Loss: 0.96268, Train Acc: 0.94253, Val Acc: 0.96610
# Epoch: 030, Loss: 0.96689, Train Acc: 0.94253, Val Acc: 0.96610
# Epoch: 031, Loss: 0.94479, Train Acc: 0.96552, Val Acc: 0.96610
# Epoch: 032, Loss: 0.92742, Train Acc: 0.98851, Val Acc: 0.96610
# Epoch: 033, Loss: 0.94100, Train Acc: 0.96552, Val Acc: 0.96610
# Epoch: 034, Loss: 0.92861, Train Acc: 0.98851, Val Acc: 0.96610
# Epoch: 035, Loss: 0.94956, Train Acc: 0.96552, Val Acc: 0.96610
# Epoch: 036, Loss: 0.94530, Train Acc: 0.97701, Val Acc: 0.96610
# Epoch: 037, Loss: 0.95270, Train Acc: 0.95402, Val Acc: 0.96610
# Epoch: 038, Loss: 0.91826, Train Acc: 1.00000, Val Acc: 0.96610
# Epoch: 039, Loss: 0.94038, Train Acc: 0.97701, Val Acc: 0.96610
# Epoch: 040, Loss: 0.94520, Train Acc: 0.97701, Val Acc: 0.94915
# Epoch: 041, Loss: 0.95136, Train Acc: 0.96552, Val Acc: 0.93220
# Epoch: 042, Loss: 0.95689, Train Acc: 0.96552, Val Acc: 0.93220
# Epoch: 043, Loss: 0.93154, Train Acc: 0.97701, Val Acc: 0.93220
# Epoch: 044, Loss: 0.94758, Train Acc: 0.96552, Val Acc: 0.93220
# Epoch: 045, Loss: 0.94098, Train Acc: 0.96552, Val Acc: 0.93220
# Epoch: 046, Loss: 0.92992, Train Acc: 0.98851, Val Acc: 0.93220
# Epoch: 047, Loss: 0.92916, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 048, Loss: 0.93682, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 049, Loss: 0.95017, Train Acc: 0.96552, Val Acc: 0.91525
# Epoch: 050, Loss: 0.94250, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 051, Loss: 0.93784, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 052, Loss: 0.97036, Train Acc: 0.93103, Val Acc: 0.91525
# Epoch: 053, Loss: 0.92694, Train Acc: 0.98851, Val Acc: 0.91525
# Epoch: 054, Loss: 0.96334, Train Acc: 0.94253, Val Acc: 0.93220
# Epoch: 055, Loss: 0.91812, Train Acc: 1.00000, Val Acc: 0.93220
# Epoch: 056, Loss: 0.95337, Train Acc: 0.96552, Val Acc: 0.94915
# Epoch: 057, Loss: 0.97435, Train Acc: 0.94253, Val Acc: 0.94915
# Epoch: 058, Loss: 0.98717, Train Acc: 0.91954, Val Acc: 0.93220
# Epoch: 059, Loss: 0.93496, Train Acc: 0.97701, Val Acc: 0.93220
# Epoch: 060, Loss: 0.95378, Train Acc: 0.96552, Val Acc: 0.93220
# Epoch: 061, Loss: 0.92733, Train Acc: 0.98851, Val Acc: 0.93220
# Epoch: 062, Loss: 0.93757, Train Acc: 0.97701, Val Acc: 0.93220
# Epoch: 063, Loss: 0.94604, Train Acc: 0.96552, Val Acc: 0.93220
# Epoch: 064, Loss: 0.93368, Train Acc: 0.97701, Val Acc: 0.93220
# Epoch: 065, Loss: 0.94912, Train Acc: 0.96552, Val Acc: 0.93220
# Epoch: 066, Loss: 0.94387, Train Acc: 0.96552, Val Acc: 0.93220
# Epoch: 067, Loss: 0.91380, Train Acc: 1.00000, Val Acc: 0.93220
# Epoch: 068, Loss: 0.94227, Train Acc: 0.96552, Val Acc: 0.93220
# Epoch: 069, Loss: 0.94623, Train Acc: 0.96552, Val Acc: 0.93220
# Epoch: 070, Loss: 0.95102, Train Acc: 0.95402, Val Acc: 0.91525
# Epoch: 071, Loss: 0.94035, Train Acc: 0.96552, Val Acc: 0.91525
# Epoch: 072, Loss: 0.93721, Train Acc: 0.97701, Val Acc: 0.91525
# Epoch: 073, Loss: 0.94072, Train Acc: 0.97701, Val Acc: 0.89831
# Epoch: 074, Loss: 0.94871, Train Acc: 0.96552, Val Acc: 0.89831
# Epoch: 075, Loss: 0.97252, Train Acc: 0.94253, Val Acc: 0.88136
# Epoch: 076, Loss: 0.94952, Train Acc: 0.96552, Val Acc: 0.88136
# Epoch: 077, Loss: 0.94051, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 078, Loss: 0.94334, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 079, Loss: 0.93981, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 080, Loss: 0.93842, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 081, Loss: 0.93368, Train Acc: 0.97701, Val Acc: 0.86441
# Epoch: 082, Loss: 0.93963, Train Acc: 0.96552, Val Acc: 0.86441
# Epoch: 083, Loss: 0.91991, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 084, Loss: 0.93662, Train Acc: 0.97701, Val Acc: 0.86441
# Epoch: 085, Loss: 0.94077, Train Acc: 0.97701, Val Acc: 0.86441
# Epoch: 086, Loss: 0.92390, Train Acc: 0.98851, Val Acc: 0.86441
# Epoch: 087, Loss: 0.92436, Train Acc: 1.00000, Val Acc: 0.88136
# Epoch: 088, Loss: 0.93344, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 089, Loss: 0.97668, Train Acc: 0.93103, Val Acc: 0.88136
# Epoch: 090, Loss: 0.93635, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 091, Loss: 0.93713, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 092, Loss: 0.94630, Train Acc: 0.96552, Val Acc: 0.88136
# Epoch: 093, Loss: 0.99508, Train Acc: 0.90805, Val Acc: 0.88136
# Epoch: 094, Loss: 0.93935, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 095, Loss: 0.93039, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 096, Loss: 0.92389, Train Acc: 1.00000, Val Acc: 0.89831
# Epoch: 097, Loss: 0.93074, Train Acc: 0.98851, Val Acc: 0.89831
# Epoch: 098, Loss: 0.94022, Train Acc: 0.97701, Val Acc: 0.88136
# Epoch: 099, Loss: 0.93995, Train Acc: 0.96552, Val Acc: 0.88136
# Epoch: 100, Loss: 0.91541, Train Acc: 1.00000, Val Acc: 0.88136
# Test Accuracy: 0.83784
# MLP
# 83.51351351351353 +- 4.5945945945945965

# %% [markdown]
# #### Visualize the results and the embedding

# %%
fig,axs = plt.subplots(1,2,figsize=(20,8))
axs[0].set_title('GCN boxplot of 10 runs')
axs[0].boxplot(global_results,labels=['GCN','MLP'])
axs[0].set_xlabel('Run')
axs[0].set_ylabel('Accuracy')
'''
axs[0,1].set_title('GCN histogram of 10 runs')
axs[0,1].bar(range(1,11),ExperimentResult)
axs[0,1].set_xticks(range(1,11))
axs[0,1].set_xlabel('Run')
axs[0,1].set_ylabel('Accuracy')
axs[0,1].plot(range(1,11),ExperimentResult,'ro',color='red')
axs[0,1].plot(range(1,11),ExperimentResult,color='red',label='Accuracy')'''

axs[1].set_title('Models lineplot of 10 runs')
axs[1].plot(range(1,11),global_results[0],'ro',color='red')
axs[1].plot(range(1,11),global_results[0],color='red',label='GCN')

axs[1].plot(range(1,11),global_results[1],'ro',color='blue')
axs[1].plot(range(1,11),global_results[1],color='blue',label='MLP')

axs[1].set_xticks(range(1,11))
axs[1].set_xlabel('Run')
axs[1].set_ylabel('Accuracy')
axs[1].legend()
fig.suptitle('GCN vs MLP')
fig.show()

# %%
from sklearn.manifold import TSNE
# Let's see the embedding of the best model over the 10 runs
# First model is GCN, second model is MLP
# GCN
out_gcn = global_best_models[0][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
'''
    Arguments of TSNE:
        * n_components: The dimension of the embedded space.
        * random_state: The seed to use for the t-SNE algorithm.
    Returns:
        * tsne_obj: The t-SNE embedding of the nodes.
'''
tsne = TSNE(n_components=2, random_state=12345)
tsne_gcn_results = tsne.fit_transform(out_gcn.detach().cpu().numpy())
# MLP
out_mlp = global_best_models[1][0](data.x, data.edge_index) # Get the output of the model with the entire dataset
tsne = TSNE(n_components=2, random_state=12345)
tsne_mlp_results = tsne.fit_transform(out_mlp.detach().cpu().numpy())
# Plot the results
fig,axs = plt.subplots(1,2,figsize=(20,10))
axs[0].set_title('GCN t-SNE')
axs[0].scatter(tsne_gcn_results[:,0],tsne_gcn_results[:,1],c=data.y,cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

axs[1].set_title('MLP t-SNE')
axs[1].scatter(tsne_mlp_results[:,0],tsne_mlp_results[:,1],c=data.y,cmap='viridis',s=60,alpha=0.85,edgecolors='black',linewidths=0.5)

fig.suptitle('t-SNE of the best model over the 10 runs',fontsize=20)
fig.show()

# %% [markdown]
# ### 3.1 Report

# %% [markdown]
# In this section we will report the results of the model. We will report the accuracy, precision, recall and F1 score for the model. We will also visualize the confusion matrix for the model using the scikit-learn library to report the results. After all, we will put the results in a markdown cell.

# %% [markdown]
# #### Report the results

# %%
# Report the best model over the 10 runs using the test set and sklearn classification report
from sklearn.metrics import classification_report
print('GCN')
print(classification_report(data.y[test_mask], global_best_models[0][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
print('========================================================================')
print('MLP')
print(classification_report(data.y[test_mask], global_best_models[1][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy()))
# Out:
# GCN
#               precision    recall  f1-score   support
#
#            0       0.71      0.56      0.63         9
#            1       0.00      0.00      0.00         3
#            2       0.00      0.00      0.00         5
#            3       0.64      0.88      0.74        16
#            4       0.75      0.75      0.75         4
#
#     accuracy                           0.59        37
#    macro avg       0.42      0.44      0.42        37
# weighted avg       0.53      0.59      0.55        37
#
# ========================================================================
# MLP
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.00      0.00      0.00         3
#            2       0.62      1.00      0.77         5
#            3       0.88      0.88      0.88        16
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.86        37
#    macro avg       0.70      0.78      0.73        37
# weighted avg       0.81      0.86      0.83        37

# %% [markdown]
# #### Exercice 1
# Explaining the metrics used in the report:
# - Accuracy:
# - Precision:
# - Recall:
# - F1 score:
# * Why is it important to report all these metrics? Did you notice that the accuracy is not the best metric to report? Why?

# %% [markdown]
# #### Confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
conf_matrix_gcn = confusion_matrix(data.y[test_mask], global_best_models[0][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
conf_matrix_mlp = confusion_matrix(data.y[test_mask], global_best_models[1][0](data.x, data.edge_index).argmax(dim=1)[test_mask].detach().cpu().numpy())
disp_gcn = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_gcn, display_labels=data.y.unique().numpy())
disp_mlp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_mlp, display_labels=data.y.unique().numpy())
fig,axs = plt.subplots(1,2,figsize=(20,10))

disp_gcn.plot(ax=axs[0])
disp_gcn.ax_.set_title('GCN Confusion Matrix')
disp_gcn.ax_.set_xlabel('Predicted label')
disp_gcn.ax_.set_ylabel('True label')
disp_gcn.im_.colorbar.remove()

disp_mlp.plot(ax=axs[1])
disp_mlp.ax_.set_title('MLP Confusion Matrix')
disp_mlp.ax_.set_xlabel('Predicted label')
disp_mlp.ax_.set_ylabel('True label')
disp_mlp.im_.colorbar.remove()

fig.suptitle('Confusion Matrix of the best model over the 10 runs',fontsize=20)
fig.show()
